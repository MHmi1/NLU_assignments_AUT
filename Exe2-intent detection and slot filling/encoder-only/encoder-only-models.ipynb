# %%
# !cp -r /content/xlm_roberta_large_best.bin /content/drive/MyDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import unicodedata

# %%
import json

def create_tokens_and_labels(id, sample):
    intent = sample['intent']
    utt = sample['utt']
    annot_utt = sample['annot_utt']
    tokens = utt.split()
    labels = []
    label = 'O'
    split_annot_utt = annot_utt.split()
    idx = 0
    BIO_SLOT = False
    while idx < len(split_annot_utt):
        if split_annot_utt[idx].startswith('['):
            label = split_annot_utt[idx].lstrip('[')
            idx += 2
            BIO_SLOT = True
        elif split_annot_utt[idx].endswith(']'):
            if split_annot_utt[idx-1] == ":":
                labels.append("B-" + label)
                label = 'O'
                idx += 1
            else:
                labels.append("I-" + label)
                label = 'O'
                idx += 1
            BIO_SLOT = False
        else:
            if split_annot_utt[idx-1] == ":":
                labels.append("B-" + label)
                idx += 1
            elif BIO_SLOT == True:
                labels.append("I-" + label)
                idx += 1
            else:
                labels.append("O")
                idx += 1

    if len(tokens) != len(labels):
        raise ValueError(f"Len of tokens, {tokens}, doesnt match len of labels, {labels}, "
                         f"for id {id} and annot utt: {annot_utt}")
    return tokens, labels, intent


def Read_Massive_dataset(massive_raw):
    sentences_tr, tags_tr, intent_tags_tr = [], [], []
    sentences_val, tags_val, intent_tags_val = [], [], []
    sentences_test, tags_test, intent_tags_test = [], [], []
    all_tags, all_intents = [], []

    for id, sample in enumerate(massive_raw):
        if sample['partition'] == 'train':
            tokens, labels, intent = create_tokens_and_labels(id, sample)
            sentences_tr.append(tokens)
            tags_tr.append(labels)
            intent_tags_tr.append(intent)
            all_tags.extend(labels)
            all_intents.append(intent)
        elif sample['partition'] == 'dev':
            tokens, labels, intent = create_tokens_and_labels(id, sample)
            sentences_val.append(tokens)
            tags_val.append(labels)
            intent_tags_val.append(intent)
        elif sample['partition'] == 'test':
            tokens, labels, intent = create_tokens_and_labels(id, sample)
            sentences_test.append(tokens)
            tags_test.append(labels)
            intent_tags_test.append(intent)

    # Unique labels and intents
    unique_tags = sorted(set(all_tags))
    unique_intents = sorted(set(all_intents))
    tag2id = {tag: i for i, tag in enumerate(unique_tags)}
    intent2id = {intent: i for i, intent in enumerate(unique_intents)}

    return (sentences_tr, tags_tr, intent_tags_tr), \
           (sentences_val, tags_val, intent_tags_val), \
           (sentences_test, tags_test, intent_tags_test), \
           tag2id, intent2id

# Download and extract MASSIVE dataset
# !gdown https://amazon-massive-nlu-dataset.s3.amazonaws.com/amazon-massive-dataset-1.0.tar.gz
# !tar -xvf /content/amazon-massive-dataset-1.0.tar.gz

#Read the dataset
massive_raw_fa = []
with open('/content/1.0/data/fa-IR.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        massive_raw_fa.append(json.loads(line))

(train_data, val_data, test_data, tag2id, intent2id) = Read_Massive_dataset(massive_raw_fa)
# Out:
# Downloading...
# From: https://amazon-massive-nlu-dataset.s3.amazonaws.com/amazon-massive-dataset-1.0.tar.gz
# To: /content/amazon-massive-dataset-1.0.tar.gz
# 100% 39.5M/39.5M [00:01<00:00, 26.8MB/s]
# 1.0/
# 1.0/CITATION.md
# 1.0/NOTICE.md
# 1.0/data/
# 1.0/data/mn-MN.jsonl
# 1.0/data/af-ZA.jsonl
# 1.0/data/el-GR.jsonl
# 1.0/data/ta-IN.jsonl
# 1.0/data/ar-SA.jsonl
# 1.0/data/ur-PK.jsonl
# 1.0/data/pl-PL.jsonl
# 1.0/data/ko-KR.jsonl
# 1.0/data/az-AZ.jsonl
# 1.0/data/da-DK.jsonl
# 1.0/data/kn-IN.jsonl
# 1.0/data/tl-PH.jsonl
# 1.0/data/is-IS.jsonl
# 1.0/data/lv-LV.jsonl
# 1.0/data/it-IT.jsonl
# 1.0/data/es-ES.jsonl
# 1.0/data/fr-FR.jsonl
# 1.0/data/ml-IN.jsonl
# 1.0/data/km-KH.jsonl
# 1.0/data/fa-IR.jsonl
# 1.0/data/sw-KE.jsonl
# 1.0/data/en-US.jsonl
# 1.0/data/tr-TR.jsonl
# 1.0/data/bn-BD.jsonl
# 1.0/data/he-IL.jsonl
# 1.0/data/te-IN.jsonl
# 1.0/data/pt-PT.jsonl
# 1.0/data/ka-GE.jsonl
# 1.0/data/ja-JP.jsonl
# 1.0/data/id-ID.jsonl
# 1.0/data/ru-RU.jsonl
# 1.0/data/hy-AM.jsonl
# 1.0/data/nb-NO.jsonl
# 1.0/data/ms-MY.jsonl
# 1.0/data/sq-AL.jsonl
# 1.0/data/sv-SE.jsonl
# 1.0/data/fi-FI.jsonl
# 1.0/data/th-TH.jsonl
# 1.0/data/de-DE.jsonl
# 1.0/data/vi-VN.jsonl
# 1.0/data/my-MM.jsonl
# 1.0/data/jv-ID.jsonl
# 1.0/data/sl-SL.jsonl
# 1.0/data/hi-IN.jsonl
# 1.0/data/nl-NL.jsonl
# 1.0/data/zh-CN.jsonl
# 1.0/data/hu-HU.jsonl
# 1.0/data/ro-RO.jsonl
# 1.0/data/zh-TW.jsonl
# 1.0/data/cy-GB.jsonl
# 1.0/data/am-ET.jsonl
# 1.0/LICENSE

# %%
import json
import random
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import XLMRobertaForSequenceClassification, XLMRobertaTokenizer, AdamW
from torch.nn import CrossEntropyLoss
import numpy as np
from tqdm import tqdm
from sklearn.metrics import f1_score, precision_recall_fscore_support, accuracy_score

# Tokenize the sentences
tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base')

def encode_data(sentences, intents, tokenizer, intent2id):
    encodings = tokenizer(sentences, is_split_into_words=True, padding=True, truncation=True, max_length=128, return_tensors='pt')
    intent_labels = [intent2id[intent] for intent in intents]
    return encodings, torch.tensor(intent_labels)

# Encode data
train_encodings, train_intents = encode_data(train_data[0], train_data[2], tokenizer, intent2id)
val_encodings, val_intents = encode_data(val_data[0], val_data[2], tokenizer, intent2id)

# Convert encodings to tensors for DataLoader
def convert_to_tensor(encodings, labels):
    input_ids = encodings['input_ids']
    attention_mask = encodings['attention_mask']
    labels = labels
    return TensorDataset(input_ids, attention_mask, labels)

train_dataset = convert_to_tensor(train_encodings, train_intents)
val_dataset = convert_to_tensor(val_encodings, val_intents)

# DataLoader for batch processing
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

# Model initialization
model = XLMRobertaForSequenceClassification.from_pretrained('xlm-roberta-base',
                                                            num_labels=len(intent2id),
                                                            ignore_mismatched_sizes=True)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Define optimizer
optimizer = AdamW(model.parameters(), lr=2e-5)

# Initialize loss function without class weights
loss_fn = CrossEntropyLoss()

def train_epoch(model, data_loader, optimizer, device, loss_fn):
    model.train()
    total_loss = 0
    correct_predictions = 0

    for data in tqdm(data_loader):
        input_ids, attention_mask, labels = [t.to(device) for t in data]

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()

        logits = outputs.logits
        _, preds = torch.max(logits, dim=1)
        correct_predictions += torch.sum(preds == labels).item()

        loss.backward()
        optimizer.step()

    return correct_predictions / len(data_loader.dataset), total_loss / len(data_loader)

def eval_model(model, data_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data in data_loader:
            input_ids, attention_mask, labels = [t.to(device) for t in data]

            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            logits = outputs.logits
            _, preds = torch.max(logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate both micro and macro metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision_micro, recall_micro, f1_micro, _ = precision_recall_fscore_support(all_labels, all_preds, average='micro')
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')

    return {
        'accuracy': accuracy,
        'precision_micro': precision_micro,
        'recall_micro': recall_micro,
        'f1_micro': f1_micro,
        'precision_macro': precision_macro,
        'recall_macro': recall_macro,
        'f1_macro': f1_macro
    }

# Early stopping parameters
patience = 4
best_val_f1 = float('-inf')  
early_stop_counter = 0

# Training loop with early stopping
epochs = 7
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    train_acc, train_loss = train_epoch(model, train_loader, optimizer, device, loss_fn)
    print(f"Train loss: {train_loss}, accuracy: {train_acc}")

    val_metrics = eval_model(model, val_loader, device)
    print(f"Validation Metrics:")
    print(f"  Accuracy: {val_metrics['accuracy']}")
    print(f"  Micro - Precision: {val_metrics['precision_micro']}, Recall: {val_metrics['recall_micro']}, F1: {val_metrics['f1_micro']}")
    print(f"  Macro - Precision: {val_metrics['precision_macro']}, Recall: {val_metrics['recall_macro']}, F1: {val_metrics['f1_macro']}")

    # Early stopping check
    if val_metrics['f1_macro'] > best_val_f1:  
        best_val_f1 = val_metrics['f1_macro']
        early_stop_counter = 0
        model.save_pretrained('xlm_roberta_large_best.bin')  # Save the best model
    else:
        early_stop_counter += 1
        if early_stop_counter >= patience:
            print("Early stopping triggered.")
            break
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/7
# 100%|██████████| 720/720 [02:24<00:00,  4.98it/s]
# Train loss: 2.322411572105355, accuracy: 0.4656939378148341
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.7456960157402853
#   Micro - Precision: 0.7456960157402853, Recall: 0.7456960157402853, F1: 0.7456960157402853
#   Macro - Precision: 0.5397439405315229, Recall: 0.5554048169085285, F1: 0.5305597699284388
# Epoch 2/7
# 100%|██████████| 720/720 [02:26<00:00,  4.92it/s]
# Train loss: 0.9307019520137045, accuracy: 0.7864339065485496
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8288243974422036
#   Micro - Precision: 0.8288243974422036, Recall: 0.8288243974422036, F1: 0.8288243974422036
#   Macro - Precision: 0.7288154775773277, Recall: 0.6939485398637507, F1: 0.6931922175270497
# Epoch 3/7
# 100%|██████████| 720/720 [02:30<00:00,  4.79it/s]
# Train loss: 0.5807530314040681, accuracy: 0.8672051415667883
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8603049680275455
#   Micro - Precision: 0.8603049680275455, Recall: 0.8603049680275455, F1: 0.8603049680275455
#   Macro - Precision: 0.8043833819069833, Recall: 0.80346470870832, F1: 0.7977478029631502
# Epoch 4/7
# 100%|██████████| 720/720 [02:26<00:00,  4.92it/s]
# Train loss: 0.4211435177363455, accuracy: 0.90055584505819
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8632562715199213
#   Micro - Precision: 0.8632562715199213, Recall: 0.8632562715199213, F1: 0.8632562715199213
#   Macro - Precision: 0.817236986014288, Recall: 0.8142945311208737, F1: 0.8083591062485576
# Epoch 5/7
# 100%|██████████| 720/720 [02:26<00:00,  4.92it/s]
# Train loss: 0.32587931454181673, accuracy: 0.92313705054716
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8612887358583374
#   Micro - Precision: 0.8612887358583374, Recall: 0.8612887358583374, F1: 0.8612887358583374
#   Macro - Precision: 0.8494674259353955, Recall: 0.8303031696767489, F1: 0.8282930331212112
# Epoch 6/7
# 100%|██████████| 720/720 [02:26<00:00,  4.92it/s]
# Train loss: 0.2661159396637231, accuracy: 0.933993399339934
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8598130841121495
#   Micro - Precision: 0.8598130841121495, Recall: 0.8598130841121495, F1: 0.8598130841121495
#   Macro - Precision: 0.7920880784142345, Recall: 0.8212252927562588, F1: 0.8025340664860299
# Epoch 7/7
# 100%|██████████| 720/720 [02:26<00:00,  4.92it/s]
# Train loss: 0.20553261004647033, accuracy: 0.9502344971339239
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8721101819970487
#   Micro - Precision: 0.8721101819970487, Recall: 0.8721101819970487, F1: 0.8721101819970487
#   Macro - Precision: 0.8539527728310824, Recall: 0.8429908507409039, F1: 0.8415897999368627

# %%
def predict_example(text, tokenizer, model, intent2id):
    model.eval()
    encoding = tokenizer(text, padding=True, truncation=True, max_length=128, return_tensors='pt')
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)

    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=1).item()
    predicted_intent = list(intent2id.keys())[list(intent2id.values()).index(predicted_class)]
    return predicted_intent

import random
num_examples = 8  
random_indices = random.sample(range(len(test_data[0])), num_examples)

for idx in random_indices:
    text = ' '.join(test_data[0][idx])  # Join tokens back into a sentence
    true_intent = test_data[2][idx]  # Get the true intent label

    predicted_intent = predict_example(text, tokenizer, model, intent2id)

    print(f"Text: {text}")
    print(f"True Intent: {true_intent}")
    print(f"Predicted Intent: {predicted_intent}")
    print("-" * 50)
# Out:
# Text: وای فای من را خاموش کن
# True Intent: iot_wemo_off
# Predicted Intent: iot_wemo_off
# --------------------------------------------------
# Text: به بیمه دی توئیت کن که آنها خیلی بد اند
# True Intent: social_post
# Predicted Intent: social_post
# --------------------------------------------------
# Text: در ساری چه کاری می‌توانم انجام دهم
# True Intent: recommendation_events
# Predicted Intent: recommendation_events
# --------------------------------------------------
# Text: دستور غذاهایی که می‌توان در یک ساعت پخت
# True Intent: cooking_recipe
# Predicted Intent: cooking_recipe
# --------------------------------------------------
# Text: برای این نشانی ایمیل بفرست.
# True Intent: email_sendemail
# Predicted Intent: email_sendemail
# --------------------------------------------------
# Text: آیا امروز هیچ ایمیل جدیدی برای من وجود دارد
# True Intent: email_query
# Predicted Intent: email_query
# --------------------------------------------------
# Text: عالی را به عنوان نظر من به این اهنگ اضافه کن
# True Intent: music_likeness
# Predicted Intent: music_likeness
# --------------------------------------------------
# Text: به من بگو اگر ایمیل‌های جدیدی دارم
# True Intent: email_query
# Predicted Intent: email_query
# --------------------------------------------------

# %%
# Function to predict for entire test set
def predict_example(text, tokenizer, model, intent2id):
    encoding = tokenizer(text, padding=True, truncation=True, max_length=128, return_tensors='pt')
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)

    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=1).item()
    predicted_intent = list(intent2id.keys())[list(intent2id.values()).index(predicted_class)]
    return predicted_intent

import pandas as pd
# Prepare data for prediction
results = []
tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-large')
# Load the model
model = XLMRobertaForSequenceClassification.from_pretrained('/content/xlm_roberta_large_best.bin')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

for idx, (sentence, true_intent, id) in enumerate(zip(test_data[0], test_data[2], [entry['id'] for entry in massive_raw_fa if entry['partition'] == 'test'])):
    text = ' '.join(sentence)  # Join tokens into text
    predicted_intent = predict_example(text, tokenizer, model, intent2id)
    results.append({
        'id': id,
        'text': text,
        'true_intent': true_intent,
        'predicted_intent': predicted_intent
    })

df_results = pd.DataFrame(results)
df_results.to_csv('fa_xlm_roberta_test_set_predictions.csv', index=False)

print("Predictions saved to 'test_set_predictions.csv'")
# Out:
# Predictions saved to 'test_set_predictions.csv'

# %%
from transformers import XLMRobertaForSequenceClassification

model = XLMRobertaForSequenceClassification.from_pretrained('xlm-roberta-base',
                                                            num_labels=len(intent2id),
                                                            ignore_mismatched_sizes=True)

total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters for xlm-roberta-base (used for persian intent det): {total_params}")
# Out:
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Total number of parameters for xlm-roberta-base (used for persian intent det): 278089788

# %% [markdown]
# # ---> Joint Bert

# %%
import json
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import XLMRobertaTokenizerFast, XLMRobertaConfig, XLMRobertaForTokenClassification, AdamW, get_linear_schedule_with_warmup
from torch.nn import CrossEntropyLoss
import numpy as np
from tqdm import tqdm
from seqeval.metrics import f1_score, precision_score, recall_score, classification_report
import pandas as pd
from seqeval.scheme import IOB2

# Load data
def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return [json.loads(line) for line in f]

# Convert to BIO format for slot filling
def convert_to_bio(utt, annot_utt):
    tokens = utt.split()
    labels = ['O'] * len(tokens)
    parts = annot_utt.split()

    i = 0
    while i < len(parts):
        if parts[i].startswith('['):
            try:
                slot_type = parts[i].split(':')[0].strip('[')
                value = parts[i].split(':')[1].strip(']')
            except IndexError:
                print(f"Warning: Malformed annotation at {i} in '{annot_utt}'")
                i += 1
                continue

            value_tokens = value.split()

            start_idx = utt.find(value, utt.find(parts[i-1] if i > 0 else '') + len(parts[i-1] if i > 0 else ''))
            if start_idx == -1:
                print(f"Warning: Slot value '{value}' not found in '{utt}'")
                i += 1
                continue
            start_token_idx = len(utt[:start_idx].split())

            for j, token in enumerate(value_tokens):
                if start_token_idx + j < len(tokens):
                    if j == 0:
                        labels[start_token_idx + j] = f'B-{slot_type}'
                    else:
                        labels[start_token_idx + j] = f'I-{slot_type}'

            i += len(value_tokens) + 1
        else:
            i += 1

    return tokens, labels

# Prepare data for both tasks
def prepare_data(data, tokenizer, label2id, intent2id):
    encodings = []
    for entry in data:
        tokens, labels = convert_to_bio(entry['utt'], entry['annot_utt'])
        encoded = tokenizer(tokens, is_split_into_words=True, padding='max_length', truncation=True, max_length=128, return_tensors='pt')

        labels_ids = []
        word_ids = encoded.word_ids(batch_index=0)
        previous_word_idx = None
        for word_idx in word_ids:
            if word_idx is None:
                labels_ids.append(-100)
            elif word_idx != previous_word_idx:
                try:
                    labels_ids.append(label2id[labels[word_idx]])
                except IndexError:
                    labels_ids.append(-100)
            else:
                labels_ids.append(-100)
            previous_word_idx = word_idx

        encodings.append({
            'input_ids': encoded['input_ids'].squeeze(),
            'attention_mask': encoded['attention_mask'].squeeze(),
            'labels': torch.tensor(labels_ids),
            'intent': torch.tensor([intent2id[entry['intent']]])
        })
    return encodings

# Load data
massive_raw_fa = load_data('/content/1.0/data/fa-IR.jsonl')
train_data, val_data, test_data = [], [], []

for entry in massive_raw_fa:
    if entry['partition'] == 'train':
        train_data.append(entry)
    elif entry['partition'] == 'dev':
        val_data.append(entry)
    elif entry['partition'] == 'test':
        test_data.append(entry)

# Get unique labels and intents
all_labels = [label for entry in train_data for label in convert_to_bio(entry['utt'], entry['annot_utt'])[1]]
unique_labels = sorted(set(all_labels))
label2id = {label: i for i, label in enumerate(unique_labels)}
id2label = {i: label for label, i in label2id.items()}

unique_intents = sorted(set([entry['intent'] for entry in train_data]))
intent2id = {intent: i for i, intent in enumerate(unique_intents)}
id2intent = {i: intent for intent, i in intent2id.items()}

# Tokenizer and model
tokenizer = XLMRobertaTokenizerFast.from_pretrained('xlm-roberta-base')
config = XLMRobertaConfig.from_pretrained('xlm-roberta-base', output_hidden_states=True, num_labels=len(label2id))

# Model: Joint BERT
class JointBERT(torch.nn.Module):
    def __init__(self, num_slot_labels, num_intent_labels):
        super(JointBERT, self).__init__()
        self.bert = XLMRobertaForTokenClassification.from_pretrained('xlm-roberta-base', config=config)
        self.intent_classifier = torch.nn.Linear(self.bert.config.hidden_size, num_intent_labels)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        if outputs.hidden_states is None:
            raise ValueError("hidden_states are not available in the model outputs. Make sure to set `output_hidden_states=True` in the config.")
        sequence_output = outputs.hidden_states[-1]  # Last hidden state for intent prediction
        pooled_output = sequence_output[:, 0]  # CLS token for intent prediction
        intent_logits = self.intent_classifier(pooled_output)
        return outputs, intent_logits

# Model initialization
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = JointBERT(num_slot_labels=len(label2id), num_intent_labels=len(intent2id))
model = model.to(device)

def convert_to_tensor(encodings):
    input_ids = torch.stack([encoding['input_ids'] for encoding in encodings])
    attention_mask = torch.stack([encoding['attention_mask'] for encoding in encodings])
    slot_labels = torch.stack([encoding['labels'] for encoding in encodings])
    intent_labels = torch.stack([encoding['intent'] for encoding in encodings])
    return TensorDataset(input_ids, attention_mask, slot_labels, intent_labels)

train_encodings = prepare_data(train_data, tokenizer, label2id, intent2id)
val_encodings = prepare_data(val_data, tokenizer, label2id, intent2id)
test_encodings = prepare_data(test_data, tokenizer, label2id, intent2id)

train_dataset = convert_to_tensor(train_encodings)
val_dataset = convert_to_tensor(val_encodings)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

# Optimizer
optimizer = AdamW(model.parameters(), lr=5e-5, weight_decay=0.01)

# Scheduler
total_steps = len(train_loader) * 10  # Assuming 10 epochs for calculation
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

# Loss functions
slot_loss_fn = CrossEntropyLoss(ignore_index=-100)
intent_loss_fn = CrossEntropyLoss()

def train_epoch(model, data_loader, optimizer, scheduler, device, slot_loss_fn, intent_loss_fn):
    model.train()
    total_slot_loss = 0
    total_intent_loss = 0
    correct_intent = 0

    for batch in tqdm(data_loader):
        input_ids, attention_mask, slot_labels, intent_labels = [t.to(device) for t in batch]

        optimizer.zero_grad()
        outputs, intent_logits = model(input_ids=input_ids, attention_mask=attention_mask, labels=slot_labels)

        slot_loss = outputs.loss
        intent_loss = intent_loss_fn(intent_logits.view(-1, len(intent2id)), intent_labels.view(-1))

        loss = slot_loss + intent_loss
        total_slot_loss += slot_loss.item()
        total_intent_loss += intent_loss.item()

        loss.backward()
        optimizer.step()
        scheduler.step()

        _, preds = torch.max(intent_logits, dim=1)
        correct_intent += torch.sum(preds == intent_labels.view(-1)).item()

    return total_slot_loss / len(data_loader), total_intent_loss / len(data_loader), correct_intent / len(train_dataset)

def eval_model(model, data_loader, device, id2label):
    model.eval()
    all_slot_preds, all_slot_true = [], []

    with torch.no_grad():
        for batch in data_loader:
            input_ids, attention_mask, slot_labels, intent_labels = [t.to(device) for t in batch]

            outputs, _ = model(input_ids=input_ids, attention_mask=attention_mask, labels=slot_labels)

            # Slot filling
            slot_predictions = torch.argmax(outputs.logits, dim=-1)
            slot_true = slot_labels.view(-1)
            mask = slot_true != -100

            true_labels = [id2label[l.item()] for l in slot_true[mask]]
            pred_labels = [id2label[l.item()] for l in slot_predictions.view(-1)[mask]]

            all_slot_preds.append(pred_labels)
            all_slot_true.append(true_labels)

    # Convert to list of lists for seqeval
    true_labels = [[label for label in seq if label != 'O'] for seq in all_slot_true]
    pred_labels = [[label for label in seq if label != 'O'] for seq in all_slot_preds]

    # Metrics calculation using seqeval
    precision_micro = precision_score(true_labels, pred_labels, mode='strict', scheme=IOB2)
    recall_micro = recall_score(true_labels, pred_labels, mode='strict', scheme=IOB2)
    f1_micro = f1_score(true_labels, pred_labels, mode='strict', scheme=IOB2)
    precision_macro = precision_score(true_labels, pred_labels, average='macro', mode='strict', scheme=IOB2)
    recall_macro = recall_score(true_labels, pred_labels, average='macro', mode='strict', scheme=IOB2)
    f1_macro = f1_score(true_labels, pred_labels, average='macro', mode='strict', scheme=IOB2)

    slot_report = classification_report(true_labels, pred_labels, mode='strict', scheme=IOB2)


    return {
        'slot_report': slot_report,
        'precision_micro': precision_micro,
        'recall_micro': recall_micro,
        'f1_micro': f1_micro,
        'precision_macro': precision_macro,
        'recall_macro': recall_macro,
        'f1_macro': f1_macro,
    }

# Training loop with early stopping
epochs = 7
best_slot_f1 = 0
best_intent_acc = 0
patience = 4
early_stopping_counter = 0

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    slot_loss, intent_loss, intent_acc = train_epoch(model, train_loader, optimizer, scheduler, device, slot_loss_fn, intent_loss_fn)
    print(f"Slot Loss: {slot_loss}, Intent Loss: {intent_loss}, Intent Accuracy: {intent_acc}")

    val_metrics = eval_model(model, val_loader, device, id2label)
    print("Validation Slot Filling Metrics:")
    print(val_metrics['slot_report'])
    print(f"Validation Slot Metrics - Micro: Precision: {val_metrics['precision_micro']:.4f}, Recall: {val_metrics['recall_micro']:.4f}, F1: {val_metrics['f1_micro']:.4f}")
    print(f"Validation Slot Metrics - Macro: Precision: {val_metrics['precision_macro']:.4f}, Recall: {val_metrics['recall_macro']:.4f}, F1: {val_metrics['f1_macro']:.4f}")

    if val_metrics['f1_macro'] > best_slot_f1:
        best_slot_f1 = val_metrics['f1_macro']
        early_stopping_counter = 0
        torch.save(model.state_dict(), 'fa_best_joint_bert_model.pth')
        print("Saved best model.")
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= patience:
            print("Early stopping triggered.")
            break

# Evaluate on test set after training
test_loader = DataLoader(convert_to_tensor(test_encodings), batch_size=16)
test_metrics = eval_model(model, test_loader, device, id2label)
print("Test Slot Filling Metrics:")
print(test_metrics['slot_report'])
print(f"Test Slot Metrics - Micro: Precision: {test_metrics['precision_micro']:.4f}, Recall: {test_metrics['recall_micro']:.4f}, F1: {test_metrics['f1_micro']:.4f}")
print(f"Test Slot Metrics - Macro: Precision: {test_metrics['precision_macro']:.4f}, Recall: {test_metrics['recall_macro']:.4f}, F1: {test_metrics['f1_macro']:.4f}")

def predict(text, tokenizer, model, label2id, id2label, intent2id, id2intent):
    model.eval()
    encoded = tokenizer(text, padding='max_length', truncation=True, max_length=128, return_tensors='pt').to(device)

    with torch.no_grad():
        outputs, intent_logits = model(**encoded)

    slot_predictions = torch.argmax(outputs.logits, dim=-1)
    slot_labels = [id2label[int(label)] for label in slot_predictions[0]]

    tokens = tokenizer.convert_ids_to_tokens(encoded['input_ids'][0])
    words = []
    last_word = ""
    for token in tokens:
        if token.startswith("##"):
            last_word += token[2:]
        else:
            if last_word:
                words.append(last_word)
            last_word = token
    if last_word:
        words.append(last_word)

    # Align predictions with words, ignoring special tokens
    slot_labels_aligned = []
    word_index = 0
    for i, token in enumerate(tokens):
        if token not in tokenizer.all_special_tokens:
            if word_index < len(words):
                slot_labels_aligned.append((words[word_index], slot_labels[i]))
                word_index += 1

    intent_prediction = id2intent[int(torch.argmax(intent_logits, dim=1)[0])]

    return slot_labels_aligned, intent_prediction

# Apply model to test set to save results in CSV
def predict_on_test_set(test_data, tokenizer, model, label2id, id2label, intent2id, id2intent):
    results = []

    for entry in test_data:
        utt = ' '.join(entry['utt'].split())  # Ensure single spaces between words
        slot_labels, predicted_intent = predict(utt, tokenizer, model, label2id, id2label, intent2id, id2intent)

        # Convert slot labels back to string format for CSV
        slot_labels_str = " ".join([f"{word}:{label}" for word, label in slot_labels])

        results.append({
            'id': entry['id'],
            'text': utt,
            'true_intent': entry['intent'],
            'predicted_intent': predicted_intent,
            'predicted_slots': slot_labels_str
        })

    return pd.DataFrame(results)

# Apply model to test set
test_results_df = predict_on_test_set(test_data, tokenizer, model, label2id, id2label, intent2id, id2intent)

# Save results to CSV
csv_file_path = 'persian_joint_bert_test_set_predictions.csv'
# Out:
# Streaming output truncated to the last 5000 lines.
# Warning: Malformed annotation at 1 in 'همه [event_name : جلسه‌های] بین [time : بیستم و بیست و سوم اردیبهشت]'
# Warning: Malformed annotation at 5 in 'همه [event_name : جلسه‌های] بین [time : بیستم و بیست و سوم اردیبهشت]'
# Warning: Malformed annotation at 0 in '[event_name : جلسات] [time : هفته اول اسفند]'
# Warning: Malformed annotation at 3 in '[event_name : جلسات] [time : هفته اول اسفند]'
# Warning: Malformed annotation at 2 in 'یک یادآوری [event_name : جلسه اداری] برای [time : سه روز بعد] تنظیم کن'
# Warning: Malformed annotation at 7 in 'یک یادآوری [event_name : جلسه اداری] برای [time : سه روز بعد] تنظیم کن'
# Warning: Malformed annotation at 2 in 'یک یادآوری [general_frequency : روزانه] برای [event_name : لباسشویی] به تقویم اضافه کن'
# Warning: Malformed annotation at 6 in 'یک یادآوری [general_frequency : روزانه] برای [event_name : لباسشویی] به تقویم اضافه کن'
# Warning: Malformed annotation at 1 in 'یک [event_name : جلسه اداری] برای [time : سه روز بعد] به تقویم اضافه کن'
# Warning: Malformed annotation at 6 in 'یک [event_name : جلسه اداری] برای [time : سه روز بعد] به تقویم اضافه کن'
# Warning: Malformed annotation at 1 in 'یک [event_name : نوبت پزشکی] برای [time : اولین روز پنج ماه آینده] به تقویم اضافه کن'
# Warning: Malformed annotation at 6 in 'یک [event_name : نوبت پزشکی] برای [time : اولین روز پنج ماه آینده] به تقویم اضافه کن'
# Warning: Malformed annotation at 0 in '[date : این هفته] [general_frequency : هر روز] یک [event_name : بازدید از خانه] را به تقویم اضافه کن'
# Warning: Malformed annotation at 4 in '[date : این هفته] [general_frequency : هر روز] یک [event_name : بازدید از خانه] را به تقویم اضافه کن'
# Warning: Malformed annotation at 9 in '[date : این هفته] [general_frequency : هر روز] یک [event_name : بازدید از خانه] را به تقویم اضافه کن'
# Warning: Malformed annotation at 0 in '[event_name : مهمانی ساحلی]'
# Warning: Malformed annotation at 0 in '[event_name : جلسه‌ی اداری] [date : هفته‌ی آینده‌ی] من رو حذف کن'
# Warning: Malformed annotation at 4 in '[event_name : جلسه‌ی اداری] [date : هفته‌ی آینده‌ی] من رو حذف کن'
# Warning: Malformed annotation at 3 in 'لطفا زمانی که [event_name : من باید برای کنفرانس بروم] به من اطلاع بده'
# Warning: Malformed annotation at 1 in 'تقویم [date : دوازده تیر]'
# Warning: Malformed annotation at 1 in 'تقویم [event_name : ملاقات] [date : مرداد]'
# Warning: Malformed annotation at 4 in 'تقویم [event_name : ملاقات] [date : مرداد]'
# Warning: Malformed annotation at 2 in 'همه رویدادهای [date : امروز] را لغو کن و من را با مشغله علامت گذاری کن'
# Warning: Malformed annotation at 5 in 'همه رویدادهای تقویم باقی مانده [date : امروز] را به عنوان پاک شده علامت‌گذاری کن'
# Warning: Malformed annotation at 0 in '[event_name : جلسه] در [place_name : شیراز] را حذف کن'
# Warning: Malformed annotation at 4 in '[event_name : جلسه] در [place_name : شیراز] را حذف کن'
# Warning: Malformed annotation at 0 in '[event_name : ازدواج] [date : سوم تیر] را پاک کن'
# Warning: Malformed annotation at 3 in '[event_name : ازدواج] [date : سوم تیر] را پاک کن'
# Warning: Malformed annotation at 0 in '[event_name : جشن تولد] را پاک کن'
# Warning: Malformed annotation at 2 in 'برای ساعت [time : پنج بعدازظهر] روز [date : سه شنبه] زنگ هشدار ایجاد کن'
# Warning: Malformed annotation at 7 in 'برای ساعت [time : پنج بعدازظهر] روز [date : سه شنبه] زنگ هشدار ایجاد کن'
# Warning: Malformed annotation at 2 in 'زنگ هشدار [time : پنج بعدازظهر] [date : سه شنبه]'
# Warning: Malformed annotation at 6 in 'زنگ هشدار [time : پنج بعدازظهر] [date : سه شنبه]'
# Warning: Malformed annotation at 1 in 'برای [time : هفته بیستم] [event_name : تمام رویدادهای آموزشی] را حذف کن'
# Warning: Malformed annotation at 5 in 'برای [time : هفته بیستم] [event_name : تمام رویدادهای آموزشی] را حذف کن'
# Warning: Malformed annotation at 1 in 'روز [date : بیست و نهم] را پاک کن'
# Warning: Malformed annotation at 0 in '[event_name : قرارهای پزشکی] [date : این آخر هفته] رو لغو کن.'
# Warning: Malformed annotation at 4 in '[event_name : قرارهای پزشکی] [date : این آخر هفته] رو لغو کن.'
# Warning: Malformed annotation at 1 in 'رویداد [event_name : عروسی مونا] را به تقویم من برای [date : سه شنبه] اضافه کن'
# Warning: Malformed annotation at 10 in 'رویداد [event_name : عروسی مونا] را به تقویم من برای [date : سه شنبه] اضافه کن'
# Warning: Malformed annotation at 2 in 'رویداد تقویم [date : سه شنبه] [event_name : عروسی مونا]'
# Warning: Malformed annotation at 6 in 'رویداد تقویم [date : سه شنبه] [event_name : عروسی مونا]'
# Warning: Malformed annotation at 1 in 'برای [event_name : جلسه] با [person : مونا] در روز [date : سه شنبه] یک یادآور رویداد بساز'
# Warning: Malformed annotation at 5 in 'برای [event_name : جلسه] با [person : مونا] در روز [date : سه شنبه] یک یادآور رویداد بساز'
# Warning: Malformed annotation at 10 in 'برای [event_name : جلسه] با [person : مونا] در روز [date : سه شنبه] یک یادآور رویداد بساز'
# Warning: Malformed annotation at 5 in 'الکسا یک یادآور رویداد برای [event_name : جلسه] با [person : مینا] در روز [date : سه شنبه] بساز'
# Warning: Malformed annotation at 9 in 'الکسا یک یادآور رویداد برای [event_name : جلسه] با [person : مینا] در روز [date : سه شنبه] بساز'
# Warning: Malformed annotation at 14 in 'الکسا یک یادآور رویداد برای [event_name : جلسه] با [person : مینا] در روز [date : سه شنبه] بساز'
# Warning: Malformed annotation at 1 in 'روز [event_name : تولد ساناز] را در [date : یک تیر] به تقویم اضافه کن'
# Warning: Malformed annotation at 7 in 'روز [event_name : تولد ساناز] را در [date : یک تیر] به تقویم اضافه کن'
# Warning: Malformed annotation at 1 in 'یک [event_name : رویداد تقویم تکرار شونده] تنظیم کن'
# Warning: Malformed annotation at 2 in 'آیا در [date : هجده فروردین] [event_name : بازی] دارم'
# Warning: Malformed annotation at 6 in 'آیا در [date : هجده فروردین] [event_name : بازی] دارم'
# Warning: Malformed annotation at 2 in 'ایا من [date : هفته آینده] [event_name : قرار ملاقات] دارم'
# Warning: Malformed annotation at 6 in 'ایا من [date : هفته آینده] [event_name : قرار ملاقات] دارم'
# Warning: Malformed annotation at 5 in 'پانزده دقیقه قبل از شروع [event_name : جلسه] به من اطلاع بده'
# Warning: Malformed annotation at 2 in 'اعلامیه برای [event_name : جلسه] تنظیم کن'
# Warning: Malformed annotation at 1 in 'برنامه [date : امروز] من را نمایش بده'
# Warning: Malformed annotation at 0 in '[date : فردا] [event_name : تولد مادرم]'
# Warning: Malformed annotation at 3 in '[date : فردا] [event_name : تولد مادرم]'
# Warning: Malformed annotation at 0 in '[date : ماه بعد] [event_name : تولد برادرم]'
# Warning: Malformed annotation at 4 in '[date : ماه بعد] [event_name : تولد برادرم]'
# Warning: Malformed annotation at 0 in '[event_name : تمام جلسه‌های] [date : امروز] را لغو کن'
# Warning: Malformed annotation at 4 in '[event_name : تمام جلسه‌های] [date : امروز] را لغو کن'
# Warning: Malformed annotation at 0 in '[date : پس فردا] [event_name : همه جلسات] برگزار خواهد شد'
# Warning: Malformed annotation at 4 in '[date : پس فردا] [event_name : همه جلسات] برگزار خواهد شد'
# Warning: Malformed annotation at 1 in 'یک [event_name : جلسه] در [place_name : اداره] در ساعت [time : یازده صبح] اضافه کن'
# Warning: Malformed annotation at 5 in 'یک [event_name : جلسه] در [place_name : اداره] در ساعت [time : یازده صبح] اضافه کن'
# Warning: Malformed annotation at 10 in 'یک [event_name : جلسه] در [place_name : اداره] در ساعت [time : یازده صبح] اضافه کن'
# Warning: Malformed annotation at 4 in 'من یک یادآوری برای [event_name : جلسه‌ی سردبیر] در ساعت [time : دو بعدازظهر] [date : پنج‌شنبه] می‌خواهم'
# Warning: Malformed annotation at 10 in 'من یک یادآوری برای [event_name : جلسه‌ی سردبیر] در ساعت [time : دو بعدازظهر] [date : پنج‌شنبه] می‌خواهم'
# Warning: Malformed annotation at 14 in 'من یک یادآوری برای [event_name : جلسه‌ی سردبیر] در ساعت [time : دو بعدازظهر] [date : پنج‌شنبه] می‌خواهم'
# Warning: Malformed annotation at 12 in 'برای من یک یادآور برای جمع شدن با کلوپ زنان در روز [date : یکشنبه] [time : بعد از مسجد] تنظیم کن'
# Warning: Malformed annotation at 15 in 'برای من یک یادآور برای جمع شدن با کلوپ زنان در روز [date : یکشنبه] [time : بعد از مسجد] تنظیم کن'
# Warning: Malformed annotation at 4 in 'من باید در یک [event_name : مسابقه‌ی آشپزی] روز [date : چهارشنبه] [time : هفت] [timeofday : صبح] شرکت کنم ذخیره کن و یک یادآوری ایجاد کن'
# Warning: Malformed annotation at 9 in 'من باید در یک [event_name : مسابقه‌ی آشپزی] روز [date : چهارشنبه] [time : هفت] [timeofday : صبح] شرکت کنم ذخیره کن و یک یادآوری ایجاد کن'
# Warning: Malformed annotation at 12 in 'من باید در یک [event_name : مسابقه‌ی آشپزی] روز [date : چهارشنبه] [time : هفت] [timeofday : صبح] شرکت کنم ذخیره کن و یک یادآوری ایجاد کن'
# Warning: Malformed annotation at 15 in 'من باید در یک [event_name : مسابقه‌ی آشپزی] روز [date : چهارشنبه] [time : هفت] [timeofday : صبح] شرکت کنم ذخیره کن و یک یادآوری ایجاد کن'
# Warning: Malformed annotation at 4 in 'برنامه من را برای [date : این ماه] پاک کن'
# Warning: Malformed annotation at 4 in 'تمام رویدادهای تقویم برای [date : اسفند] را پاک کن'
# Warning: Malformed annotation at 0 in '[event_name : جلسه برنامه‌ریزی شده با اکبر] در [date : یک فروردین] را حذف کن'
# Warning: Malformed annotation at 8 in '[event_name : جلسه برنامه‌ریزی شده با اکبر] در [date : یک فروردین] را حذف کن'
# Warning: Malformed annotation at 0 in '[event_name : نوبت دکتر] را حذف کن من برای ساعت [time : نه صبح] [date : بیست و چهارم بهمن] به تقویم خود اضافه کرده بودم'
# Warning: Malformed annotation at 10 in '[event_name : نوبت دکتر] را حذف کن من برای ساعت [time : نه صبح] [date : بیست و چهارم بهمن] به تقویم خود اضافه کرده بودم'
# Warning: Malformed annotation at 14 in '[event_name : نوبت دکتر] را حذف کن من برای ساعت [time : نه صبح] [date : بیست و چهارم بهمن] به تقویم خود اضافه کرده بودم'
# Warning: Malformed annotation at 0 in '[event_name : نوبت دکتر] من برای [date : دوازدهم اسفند] را حذف کن'
# Warning: Malformed annotation at 6 in '[event_name : نوبت دکتر] من برای [date : دوازدهم اسفند] را حذف کن'
# Warning: Malformed annotation at 1 in 'لطفاً [event_name : وقت دکتر] [date : اول اسفند] در ساعت [time : نه صبح] را در تقویم من حذف کن'
# Warning: Malformed annotation at 5 in 'لطفاً [event_name : وقت دکتر] [date : اول اسفند] در ساعت [time : نه صبح] را در تقویم من حذف کن'
# Warning: Malformed annotation at 11 in 'لطفاً [event_name : وقت دکتر] [date : اول اسفند] در ساعت [time : نه صبح] را در تقویم من حذف کن'
# Warning: Malformed annotation at 2 in 'آیا برای [time : یک بعدازظهر] [date : دوشنبه] آینده برنامه‌ای دارم'
# Warning: Malformed annotation at 6 in 'آیا برای [time : یک بعدازظهر] [date : دوشنبه] آینده برنامه‌ای دارم'
# Warning: Malformed annotation at 1 in 'آیا [event_name : قراری] برای [date : شنبه] تنظیم شده بود'
# Warning: Malformed annotation at 5 in 'آیا [event_name : قراری] برای [date : شنبه] تنظیم شده بود'
# Warning: Malformed annotation at 5 in 'چند گروه دیگر در کنسرت [event_name : بیست و پنج باند] در [date : پنجم فروردین] اجرا خواهند کرد'
# Warning: Malformed annotation at 12 in 'چند گروه دیگر در کنسرت [event_name : بیست و پنج باند] در [date : پنجم فروردین] اجرا خواهند کرد'
# Warning: Malformed annotation at 0 in '[event_name : شب قدر هزار و سیصد و نود و هفت] را در [date : بیست و پنج فروردین] در تقویم یادداشت کن'
# Warning: Malformed annotation at 13 in '[event_name : شب قدر هزار و سیصد و نود و هفت] را در [date : بیست و پنج فروردین] در تقویم یادداشت کن'
# Warning: Malformed annotation at 9 in 'زنگ هشدار را برای یادآوری این رویداد تنظیم کن [event_name : که ده بار تکرار شود]'
# Warning: Malformed annotation at 0 in '[event_name : جلسه پروژه] من در چه ساعتی است'
# Warning: Malformed annotation at 0 in '[date : پس از چند روز] به من در مورد [event_name : جلسات] من اطلاع بده'
# Warning: Malformed annotation at 10 in '[date : پس از چند روز] به من در مورد [event_name : جلسات] من اطلاع بده'
# Warning: Malformed annotation at 4 in 'در طول چند روز [event_name : جلسات] را به من یادآوری کن'
# Warning: Malformed annotation at 2 in 'در مورد [event_name : جلسه] در یک دوره زمانی به من بگو'
# Warning: Malformed annotation at 1 in 'می‌توانی [event_name : جلسه کاری] من را به تقویم [event_name : کاری] اضافه کنی'
# Warning: Malformed annotation at 9 in 'می‌توانی [event_name : جلسه کاری] من را به تقویم [event_name : کاری] اضافه کنی'
# Warning: Malformed annotation at 0 in '[event_name : وقت] بعدی [event_name : دندانپزشکی] من کی است'
# Warning: Malformed annotation at 4 in '[event_name : وقت] بعدی [event_name : دندانپزشکی] من کی است'
# Warning: Malformed annotation at 0 in '[event_name : وقت چشم پزشکی] من در تاریخ [date : بیست و سوم] ساعت چنده'
# Warning: Malformed annotation at 8 in '[event_name : وقت چشم پزشکی] من در تاریخ [date : بیست و سوم] ساعت چنده'
# Warning: Malformed annotation at 4 in 'رویداد را در تاریخ [date : سی مرداد] ساعت [time : نه صبح] اضافه کن'
# Warning: Malformed annotation at 9 in 'رویداد را در تاریخ [date : سی مرداد] ساعت [time : نه صبح] اضافه کن'
# Warning: Malformed annotation at 2 in 'جلسه در [date : سه شنبه] را برنامه‌ریزی کن'
# Warning: Malformed annotation at 1 in 'برنامه [date : دوشنبه] آینده چگونه است'
# Warning: Malformed annotation at 2 in 'سلام لطفا [time : تا پایان روز] اطلاعاتی در مورد رویدادها ارائه بده'
# Warning: Malformed annotation at 0 in '[time : قبل از پایان شیفت] به اطلاعاتی در مورد رویدادها نیاز دارم'
# Warning: Malformed annotation at 0 in '[date : پنج‌شنبه] آینده چه [event_name : جلساتی] دارم'
# Warning: Malformed annotation at 5 in '[date : پنج‌شنبه] آینده چه [event_name : جلساتی] دارم'
# Warning: Malformed annotation at 1 in 'ایا [date : این ماه] [event_name : ملاقات گروهی] در برنامه هست'
# Warning: Malformed annotation at 5 in 'ایا [date : این ماه] [event_name : ملاقات گروهی] در برنامه هست'
# Warning: Malformed annotation at 6 in 'این برنامه ی تقویم را هرروز [event_name : تکرار] کن'
# Warning: Malformed annotation at 3 in 'من می خواهم [event_name : رویداد عروسی] را در روز [date : شنبه] حذف کنم'
# Warning: Malformed annotation at 10 in 'من می خواهم [event_name : رویداد عروسی] را در روز [date : شنبه] حذف کنم'
# Warning: Malformed annotation at 2 in 'من برای [date : جمعه] چی برنامه‌ریزی کردم'
# Warning: Malformed annotation at 4 in 'چه زمانی قرار است [date : این هفته] [event_name : سمیرا را] برای [meal_type : ناهار] [event_name : ببینم]'
# Warning: Malformed annotation at 8 in 'چه زمانی قرار است [date : این هفته] [event_name : سمیرا را] برای [meal_type : ناهار] [event_name : ببینم]'
# Warning: Malformed annotation at 13 in 'چه زمانی قرار است [date : این هفته] [event_name : سمیرا را] برای [meal_type : ناهار] [event_name : ببینم]'
# Warning: Malformed annotation at 16 in 'چه زمانی قرار است [date : این هفته] [event_name : سمیرا را] برای [meal_type : ناهار] [event_name : ببینم]'
# Warning: Malformed annotation at 1 in 'قرار [meal_type : نهار] من برای [date : دوشنبه] ها را به من یادآوری کن'
# Warning: Malformed annotation at 6 in 'قرار [meal_type : نهار] من برای [date : دوشنبه] ها را به من یادآوری کن'
# Warning: Malformed annotation at 5 in 'لطفا یک ساعت قبل از [event_name : قرار موی] [date : پنج‌شنبه] من به من خبر بده'
# Warning: Malformed annotation at 9 in 'لطفا یک ساعت قبل از [event_name : قرار موی] [date : پنج‌شنبه] من به من خبر بده'
# Warning: Malformed annotation at 2 in 'من باید [event_name : تمرین بیسبال] را در روز [date : شنبه] ساعت [time : دو بعدازظهر] اضافه کنم'
# Warning: Malformed annotation at 9 in 'من باید [event_name : تمرین بیسبال] را در روز [date : شنبه] ساعت [time : دو بعدازظهر] اضافه کنم'
# Warning: Malformed annotation at 13 in 'من باید [event_name : تمرین بیسبال] را در روز [date : شنبه] ساعت [time : دو بعدازظهر] اضافه کنم'
# Warning: Malformed annotation at 2 in 'آیا برای [date : چهاردهم دی] قراری دارم'
# Warning: Malformed annotation at 6 in 'آیا رویدادی در تقویم من برای [date : این هفته] وجود دارد'
# Warning: Malformed annotation at 7 in 'اوولی آیا رویدادی در تقویم من برای [date : این هفته] وجود دارد'
# Warning: Malformed annotation at 4 in 'olly یک یادآوری برای [event_name : ملاقات] [date : امروز] من تنظیم کن'
# Warning: Malformed annotation at 7 in 'olly یک یادآوری برای [event_name : ملاقات] [date : امروز] من تنظیم کن'
# Warning: Malformed annotation at 1 in 'برای [event_name : جلسه] [date : امروز] من یک یادآور تنطیم کن'
# Warning: Malformed annotation at 4 in 'برای [event_name : جلسه] [date : امروز] من یک یادآور تنطیم کن'
# Warning: Malformed annotation at 0 in '[time : دو ساعت] قبل از [event_name : جلسه] به من اطلاع بده'
# Warning: Malformed annotation at 6 in '[time : دو ساعت] قبل از [event_name : جلسه] به من اطلاع بده'
# Warning: Malformed annotation at 5 in 'اوولی چند ساعت قبل زمان [event_name : جلسه] بعدی را به من یادآوری کن'
# Warning: Malformed annotation at 5 in 'چند ساعت قبل از زمان [event_name : جلسه] بعدی را به من یادآوری کن'
# Warning: Malformed annotation at 1 in 'برای [date : شنبه] بعد ساعت [time : ده صبح] [event_name : رویداد تقویم را خالی کن]'
# Warning: Malformed annotation at 6 in 'برای [date : شنبه] بعد ساعت [time : ده صبح] [event_name : رویداد تقویم را خالی کن]'
# Warning: Malformed annotation at 10 in 'برای [date : شنبه] بعد ساعت [time : ده صبح] [event_name : رویداد تقویم را خالی کن]'
# Warning: Malformed annotation at 4 in 'لطفاً در تقویم برای [date : شنبه] آینده ساعت [time : ده صبح] یک مورد وارد کن'
# Warning: Malformed annotation at 9 in 'لطفاً در تقویم برای [date : شنبه] آینده ساعت [time : ده صبح] یک مورد وارد کن'
# Warning: Malformed annotation at 0 in '[event_name : جلسه] با [relation : دندانپزشک] در [date : دوم خرداد] را به من یادآوری کن'
# Warning: Malformed annotation at 4 in '[event_name : جلسه] با [relation : دندانپزشک] در [date : دوم خرداد] را به من یادآوری کن'
# Warning: Malformed annotation at 8 in '[event_name : جلسه] با [relation : دندانپزشک] در [date : دوم خرداد] را به من یادآوری کن'
# Warning: Malformed annotation at 2 in 'آیا برای [date : امروز] برنامه‌ای دارم'
# Warning: Malformed annotation at 1 in 'رویداد [event_name : مهمانی] را از تقویم حذف کن'
# Warning: Malformed annotation at 1 in 'رویداد [event_name : سفر] را حذف کن'
# Warning: Malformed annotation at 2 in 'همه رویدادهای [date : بیست و ششم اسفند] را حذف کن'
# Warning: Malformed annotation at 3 in 'یک یادآور برای [event_name : جلسه] با [person : اکبر] در روز [date : چهارشنبه] [time : نه صبح] تنظیم کن'
# Warning: Malformed annotation at 7 in 'یک یادآور برای [event_name : جلسه] با [person : اکبر] در روز [date : چهارشنبه] [time : نه صبح] تنظیم کن'
# Warning: Malformed annotation at 12 in 'یک یادآور برای [event_name : جلسه] با [person : اکبر] در روز [date : چهارشنبه] [time : نه صبح] تنظیم کن'
# Warning: Malformed annotation at 15 in 'یک یادآور برای [event_name : جلسه] با [person : اکبر] در روز [date : چهارشنبه] [time : نه صبح] تنظیم کن'
# Warning: Malformed annotation at 1 in 'یادآور [event_name : تولد] من برای [date : هفته آینده] را حذف کن'
# Warning: Malformed annotation at 6 in 'یادآور [event_name : تولد] من برای [date : هفته آینده] را حذف کن'
# Warning: Malformed annotation at 3 in 'لطفا رویدادهای ماه [date : اسفند] را پیدا کن'
# Warning: Malformed annotation at 2 in 'رویدادهای منطقه [place_name : ساری] را جستجو کن'
# Warning: Malformed annotation at 7 in 'من میخوام رویدادهای برنامه ریزی شده ی [time : همین آخر هفته] را بدانم'
# Warning: Malformed annotation at 4 in 'لطفا یادآوری کن که [event_name : برای جلسه دونات بگیرم]'
# Warning: Malformed annotation at 1 in 'ظرف [time : یک ساعت] برای یک [event_name : جلسه] یادآوری تنظیم کن'
# Warning: Malformed annotation at 7 in 'ظرف [time : یک ساعت] برای یک [event_name : جلسه] یادآوری تنظیم کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 1 in 'در [app_name : پاندورا] ایستگاه [music_genre : راک] من را پخش کن'
# Warning: Malformed annotation at 5 in 'در [app_name : پاندورا] ایستگاه [music_genre : راک] من را پخش کن'
# Warning: Malformed annotation at 4 in 'ایستگاه های رادیویی جدید [music_genre : راک] کدام ها هستند'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : trance music] در رادیو پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : بهترین] کانال رادیویی را برایم پخش کن'
# Warning: Malformed annotation at 1 in 'رادیو [app_name : پاندورا] پخش کن.'
# Warning: Malformed annotation at 3 in 'olly لطفا رادیو [app_name : pandora] را پخش کن'
# Warning: Malformed annotation at 2 in 'امیر ایستگاه [radio_name : رادیو جوان] را روشن کن'
# Warning: Malformed annotation at 0 in '[app_name : اسپاتیفای] بزار'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 1 in 'میتونی [radio_name : رادیو جوان] بدون هیچ تبلیغی پخش کنی'
# Warning: Malformed annotation at 5 in 'من میخوام بهترین آهنگ های [music_genre : کانتری] دهه [time : شصت] را گوش بدم'
# Warning: Malformed annotation at 9 in 'من میخوام بهترین آهنگ های [music_genre : کانتری] دهه [time : شصت] را گوش بدم'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را پخش کن'
# Warning: Malformed annotation at 3 in 'برای من ایستگاه [radio_name : رادیو خبر] را پیدا کن'
# Warning: Malformed annotation at 1 in 'اگه [person : امیر] هست بیارش روی خط'
# Warning: Malformed annotation at 5 in 'من میخوام چند تا رادیو [music_genre : پاپ] گوش بدم'
# Warning: Malformed annotation at 4 in 'برو توی رادیو و [radio_name : رادیو جوان] رو پخش کن'
# Warning: Malformed annotation at 5 in 'در رادیو الان زمان پخش [media_type : موسیقی] خوب است'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو کافه] پخش کن.'
# Warning: Malformed annotation at 1 in 'فقط [radio_name : رادیو ورزش] پخش کن.'
# Warning: Malformed annotation at 5 in 'رادیو بهتره فقط روی موج [radio_name : رادیو ورزش] باشه'
# Warning: Malformed annotation at 7 in 'رادیو را روشن کن و به فرکانس [radio_name : رادیو جوان] برو'
# Warning: Malformed annotation at 7 in 'رادیو را روشن کن و به فرکانس [radio_name : رادیو خبر] برو'
# Warning: Malformed annotation at 7 in 'رادیو را روشن کن و به فرکانس [radio_name : رادیو ورزش] برو'
# Warning: Malformed annotation at 4 in 'به دنبال ایستگاه رادیویی [radio_name : رادیو خبر] در فرکانس یک بگرد'
# Warning: Malformed annotation at 6 in 'ایستگاه رادیویی را برایم بیار که [music_genre : اهنگ کلاسیک] پخش کند'
# Warning: Malformed annotation at 1 in 'من [radio_name : رادیو ورزش] را میخواهم لطفا'
# Warning: Malformed annotation at 3 in 'من دوست دارم [radio_name : رادیو جوان] گوش بدم'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : رادیو راه] را روشن کن'
# Warning: Malformed annotation at 4 in 'وقت گوش دادن به [radio_name : رادیو جوان] است'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو کرج] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : موج اف. ام.] را پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر]'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : رادیو راه] را روشن کن'
# Warning: Malformed annotation at 4 in 'من میخوام که تو [radio_name : رادیو راه] را پخش کنی'
# Warning: Malformed annotation at 0 in '[radio_name : ایستگاه بعدی] را جستجو کن'
# Warning: Malformed annotation at 2 in 'من میخوام [radio_name : رادیو ورزش] گوش بدم'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 1 in 'کانال [radio_name : رادیو جوان] را برای من پیدا کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو کافه] را روشن کن'
# Warning: Malformed annotation at 0 in '[device_type : شبکه رادیویی] مورد علاقه من را پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو صبحگاهی] را میتوانی روشن کنی لطفا'
# Warning: Malformed annotation at 1 in 'از [app_name : پاندورا] خسته شدم لطفا رادیو روشن کن'
# Warning: Malformed annotation at 2 in 'نرم افزار [app_name : پاندورا] را باز کن'
# Warning: Malformed annotation at 0 in '[app_name : پاندورا] را باز کن و ایستگاه آهنگ [music_genre : راک کلاسیک] را جستجو کن'
# Warning: Malformed annotation at 9 in '[app_name : پاندورا] را باز کن و ایستگاه آهنگ [music_genre : راک کلاسیک] را جستجو کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 7 in 'رادیو را روشن کن و روی موج [radio_name : رادیو جوان] بزار'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 1 in 'در [device_type : رادیو ماهواره ای] [app_name : sirius] را بیاور'
# Warning: Malformed annotation at 6 in 'در [device_type : رادیو ماهواره ای] [app_name : sirius] را بیاور'
# Warning: Malformed annotation at 3 in 'من میخوام به [radio_name : رادیو ورزش] گوش بدم لطفا'
# Warning: Malformed annotation at 1 in 'میتونی [music_genre : دریا دریا] را برای من پخش کنی'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : رادیو ورزش] بزار'
# Warning: Malformed annotation at 2 in 'رادیو کانال [radio_name : ده] رو باز کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] بزار'
# Warning: Malformed annotation at 5 in 'لطفا چند تا آهنگ برای [relation : کودکان] پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را برای من پیدا کن'
# Warning: Malformed annotation at 1 in 'لطفا [media_type : رادیو راه] را روشن کن'
# Warning: Malformed annotation at 3 in 'کانال را به [radio_name : رادیو جوان] تغییر بده'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را در رادیو روشن کن'
# Warning: Malformed annotation at 5 in 'لطفا در رادیو به موج [radio_name : رادیو خبر] برو'
# Warning: Malformed annotation at 1 in 'بهترین [radio_name : ایستگاه رادیویی راک] نزدیک موقعیت مکانی من را پیدا کن و پخش کن'
# Warning: Malformed annotation at 2 in 'نزدیک ترین [radio_name : ایستگاه رادیویی راک] را پیدا کن'
# Warning: Malformed annotation at 5 in 'رادیو را روشن کن و [radio_name : رادیو راه] پخش کن'
# Warning: Malformed annotation at 5 in 'میتونی آن ایستگاه رادیویی در [app_name : اسپاتیفای] را که [date : دیروز] گوش میدادم پیدا کنی'
# Warning: Malformed annotation at 10 in 'میتونی آن ایستگاه رادیویی در [app_name : اسپاتیفای] را که [date : دیروز] گوش میدادم پیدا کنی'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را پخش کن'
# Warning: Malformed annotation at 3 in 'برای من الان [radio_name : مونولوگ] پخش کن'
# Warning: Malformed annotation at 3 in 'در رادیو ماشین [radio_name : رادیو جوان] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو راه] را روشن کن لطفا'
# Warning: Malformed annotation at 5 in 'رادیو را روشن کن و [radio_name : رادیو ورزش] را پخش کن'
# Warning: Malformed annotation at 6 in 'لطفا رادیو راه من را روی [radio_name : بی. بی. سی.] تنظیم کن'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : برنامه صبحگاهی] مورد علاقه م رو در طول راه پخش کن.'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] بزار'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را در رادیو پخش کن'
# Warning: Malformed annotation at 2 in 'من میخوام [radio_name : رادیو راه] گوش بدم'
# Warning: Malformed annotation at 1 in 'می‌تونی [radio_name : رادیو ورزش] رو باز کنی'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] پخش کن.'
# Warning: Malformed annotation at 1 in 'به [radio_name : رادیو جوان] گوش بده'
# Warning: Malformed annotation at 3 in 'چند تا آهنگ [music_genre : کانتری] پخش کن'
# Warning: Malformed annotation at 1 in 'به [radio_name : رادیو ورزش] گوش بده'
# Warning: Malformed annotation at 2 in 'پلی لیست [playlist_name : عشق] رو از [app_name : گوگل پلی] پخش کن'
# Warning: Malformed annotation at 7 in 'پلی لیست [playlist_name : عشق] رو از [app_name : گوگل پلی] پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را در [app_name : sirius] پخش کن'
# Warning: Malformed annotation at 6 in '[radio_name : رادیو جوان] را در [app_name : sirius] پخش کن'
# Warning: Malformed annotation at 2 in 'نرم افزار [app_name : sirius] را باز کن و [radio_name : رادیو جوان] را پخش کن'
# Warning: Malformed annotation at 9 in 'نرم افزار [app_name : sirius] را باز کن و [radio_name : رادیو جوان] را پخش کن'
# Warning: Malformed annotation at 0 in '[app_name : اسپاتیفای] را باز کن و کانال شخصی من را پخش کن'
# Warning: Malformed annotation at 2 in 'برای من [radio_name : رادیو خبر] را پیدا کن'
# Warning: Malformed annotation at 6 in 'جدیدترین فایل های صوتی من از [podcast_name : radiolab] را پخش کن'
# Warning: Malformed annotation at 4 in 'در لیست پخش موزیک [music_genre : ایرانی] بزار'
# Warning: Malformed annotation at 5 in 'یک برنامه گفتگو در مورد [radio_name : مراقبت از کودکان] پخش کن'
# Warning: Malformed annotation at 3 in 'یک برنامه از [radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 7 in 'لطفا برترین های دهه چهل را در [app_name : پاندورا] پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] من رو باز کن'
# Warning: Malformed annotation at 5 in 'من میخوام به قسمت جدید [person : علی] گوش بدم'
# Warning: Malformed annotation at 2 in 'در رادیو [person : امیر] را پخش کن'
# Warning: Malformed annotation at 4 in 'در رادیو به دنبال [person : امیر] بگرد'
# Warning: Malformed annotation at 3 in 'من میخوام در [house_place : هال] [radio_name : رادیو جوان] گوش بدم'
# Warning: Malformed annotation at 6 in 'من میخوام در [house_place : هال] [radio_name : رادیو جوان] گوش بدم'
# Warning: Malformed annotation at 2 in 'میشه لطفا [radio_name : رادیو ورزش] را در جایی که من هستم روشن کنی'
# Warning: Malformed annotation at 4 in 'شوی سلامت رو روی [device_type : موبایلم] پخش کن'
# Warning: Malformed annotation at 3 in 'برنامه سلامت در [house_place : آشپزخانه] رو پخش کن'
# Warning: Malformed annotation at 1 in 'رادیو [app_name : پاندورای] من را روشن کن'
# Warning: Malformed annotation at 2 in 'لیست پخش [music_genre : غیرعادی] در رادیوی من را روشن کن'
# Warning: Malformed annotation at 1 in 'رادیوی [radio_name : محلی] را روشن کن'
# Warning: Malformed annotation at 0 in '[music_genre : کانتری] پخش کن'
# Warning: Malformed annotation at 0 in '[music_genre : راک] پخش کن'
# Warning: Malformed annotation at 2 in 'من میخوام [radio_name : رادیو جوان] گوش بدم'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را روشن کن'
# Warning: Malformed annotation at 3 in 'لطفا برو روی [radio_name : رادیو خبر]'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : رادیو خبر] را پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] پخش کن.'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو کافه] را روشن کن'
# Warning: Malformed annotation at 3 in 'شروع به پخش [radio_name : رادیو خبر] بکن'
# Warning: Malformed annotation at 0 in '[app_name : پاندورا] را روشن کن'
# Warning: Malformed annotation at 2 in 'می‌تونی لطفا [radio_name : رادیو جوان] رو روی موج اف. ام. برام پخش کنی'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : کانال خبری] را پخش کن که بتونم چند تا خبر گوش بدم'
# Warning: Malformed annotation at 1 in 'ایستگاه [music_genre : جاز] را روشن کن'
# Warning: Malformed annotation at 3 in 'یک ایستگاه رادیویی [music_genre : کلاسیک] برای من روشن کن'
# Warning: Malformed annotation at 2 in 'من میخوام [music_genre : راک] گوش بدم'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را روشن کن'
# Warning: Malformed annotation at 3 in 'رادیو جوان در [app_name : sirius] پخش کن'
# Warning: Malformed annotation at 1 in 'روی [app_name : sirius] ابی رو بگیر برام'
# Warning: Malformed annotation at 4 in 'اوولی من میخوام به [radio_name : رادیو ورزش] گوش بدم'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : شبکه ورزشی] را برای هاکی روشن کن'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : شوی رنگارنگ] داغ [date : دیروز] را پخش کن'
# Warning: Malformed annotation at 6 in 'لطفا [radio_name : شوی رنگارنگ] داغ [date : دیروز] را پخش کن'
# Warning: Malformed annotation at 3 in 'ترس را در [radio_name : رادیو آوا] پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را روشن کن'
# Warning: Malformed annotation at 1 in 'کمی [music_genre : سافت راک] پخش کن'
# Warning: Malformed annotation at 2 in 'چند تا [music_genre : آهنگ عاشقانه] پخش کن'
# Warning: Malformed annotation at 1 in 'ساعت [time : یک شب] [radio_name : رادیو راه] را روشن کن'
# Warning: Malformed annotation at 5 in 'ساعت [time : یک شب] [radio_name : رادیو راه] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو آوا] رو باز کن'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : رادیو آوا] پخش کن'
# Warning: Malformed annotation at 1 in 'من [media_type : موزیک] میخوام'
# Warning: Malformed annotation at 6 in 'پادکست علی بندری رو توی رادیو [house_place : هال] پخش کن'
# Warning: Malformed annotation at 6 in 'برنامه‌ی این زندگی آمریکایی رو روی [device_type : رادیوی ماشین] پخش کن'
# Warning: Malformed annotation at 4 in 'رادیو را روی موج [radio_name : رادیو خبر] بزار'
# Warning: Malformed annotation at 2 in 'فرکانس رادیوی [radio_name : نود و نه ممیز پنج] رو باز کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو کافه] را روشن کن'
# Warning: Malformed annotation at 1 in 'در [radio_name : رادیو آوا] [music_genre : هیپ هاپ] پخش کن'
# Warning: Malformed annotation at 5 in 'در [radio_name : رادیو آوا] [music_genre : هیپ هاپ] پخش کن'
# Warning: Malformed annotation at 0 in '[person : دکتر مسعود صابری] را در [device_type : رادیو کنار تخت] پخش کن'
# Warning: Malformed annotation at 7 in '[person : دکتر مسعود صابری] را در [device_type : رادیو کنار تخت] پخش کن'
# Warning: Malformed annotation at 1 in 'فایل [person : علی] را بیار و آن را کنار تخت من پخش کن'
# Warning: Malformed annotation at 2 in 'میتونی لطفا [media_type : آهنگ] بزاری'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] رو پخش کن'
# Warning: Malformed annotation at 0 in '[timeofday : صبح] به جای هشدار رادیو پخش کن.'
# Warning: Malformed annotation at 1 in 'رادیو [person : فاطمه] را پخش کن'
# Warning: Malformed annotation at 5 in 'لطفا ایستگاه رادیویی را به [radio_name : رادیو جوان] تغییر بده'
# Warning: Malformed annotation at 4 in 'ایستگاه رادیویی را به [radio_name : رادیو خبر] تغییر بده'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو اوا] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو چهار] پخش کن.'
# Warning: Malformed annotation at 4 in 'برنامه قصه شب در [radio_name : رادیو جوان]'
# Warning: Malformed annotation at 0 in '[person : امیر] پخش کن'
# Warning: Malformed annotation at 2 in 'من میخوام [radio_name : رادیو جوان] گوش بدم'
# Warning: Malformed annotation at 1 in 'میتونی [person : امیر] را پخش کنی'
# Warning: Malformed annotation at 2 in 'میتونی برنامه‌های [radio_name : رادیو خبر] رو پخش کنی'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر]'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : صدای آشنا] را در [radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 7 in 'لطفا [radio_name : صدای آشنا] را در [radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 2 in 'الکسا روی [radio_name : موج ای. ام. رادیو ورزش] رو پخش کن'
# Warning: Malformed annotation at 1 in 'الکسا [radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو ورزش] را پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را روشن کن'
# Warning: Malformed annotation at 2 in 'نرم افزار [app_name : پاندورا] را باز کن و [radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 9 in 'نرم افزار [app_name : پاندورا] را باز کن و [radio_name : رادیو ورزش] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را از نرم افزار [app_name : پاندورای] من پخش کن'
# Warning: Malformed annotation at 8 in '[radio_name : رادیو جوان] را از نرم افزار [app_name : پاندورای] من پخش کن'
# Warning: Malformed annotation at 0 in '[app_name : پاندورا] را باز کن و [radio_name : رادیو جوان] بزار'
# Warning: Malformed annotation at 7 in '[app_name : پاندورا] را باز کن و [radio_name : رادیو جوان] بزار'
# Warning: Malformed annotation at 0 in '[radio_name : ایستگاه های رادیویی فلوریدا] کدام ها هستند'
# Warning: Malformed annotation at 1 in 'لطفا [radio_name : رادیو نما] پخش کن'
# Warning: Malformed annotation at 3 in 'برنامه های بعدی [radio_name : رادیو راه] رو بهم‌ نشون بده'
# Warning: Malformed annotation at 2 in 'وقتی تو [house_place : آشپزخانه] ام رادیو آوا پخش کن.'
# Warning: Malformed annotation at 3 in 'من میخوام در [radio_name : رادیو جوان] به قصه شب گوش بدم'
# Warning: Malformed annotation at 5 in 'رادیو را روشن کن و [radio_name : رادیو خبر] را بیار'
# Warning: Malformed annotation at 4 in 'لطفا شوی صبحگاهی در [radio_name : رادیو خبر] را پخش کن'
# Warning: Malformed annotation at 6 in 'می تونی برنامه قرائتی رو روی [radio_name : رادیو قرآن] پیدا کنی'
# Warning: Malformed annotation at 5 in 'آهنگ بچه محل رو از [radio_name : رادیو جوان] پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو آوا] پخش کن.'
# Warning: Malformed annotation at 2 in 'پلی لیست [music_descriptor : موسیقی ورزشی] [app_name : پاندورا] رو پخش کن.'
# Warning: Malformed annotation at 6 in 'پلی لیست [music_descriptor : موسیقی ورزشی] [app_name : پاندورا] رو پخش کن.'
# Warning: Malformed annotation at 4 in 'کانال رادیویی که آهنگ [music_genre : راک] میگزارد را پخش کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو خبر] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو آوا] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو] را روشن کن'
# Warning: Malformed annotation at 0 in '[radio_name : رادیو جوان] را روشن کن'
# Warning: Malformed annotation at 1 in 'به [app_name : sirius] برو و کانال هیپ هاپ را پخش کن'
# Warning: Malformed annotation at 7 in 'من میخوام به برنامه ی یک در [radio_name : رادیو جوان] گوش بدم'
# Warning: Malformed annotation at 1 in 'اوولی [app_name : netflix] را در [device_type : p. s. four] من پخش کن'
# Warning: Malformed annotation at 6 in 'اوولی [app_name : netflix] را در [device_type : p. s. four] من پخش کن'
# Warning: Malformed annotation at 5 in 'اوولی یک فیلم خوب در [device_type : تلویزیون] من پخش کن'
# Warning: Malformed annotation at 4 in 'یک فیلم خوب از [device_type : تلویزیون] من پخش کن'
# Warning: Malformed annotation at 4 in 'اوولی برای من آهنگ [music_descriptor : upbeat] از اسپیکر پخش کن'
# Warning: Malformed annotation at 2 in 'من میخواهم [radio_name : رادیو جوان] گوش کنم'
# Warning: Malformed annotation at 2 in 'کتاب صوتی [time : سی ثانیه] [player_setting : عقب بره]'
# Warning: Malformed annotation at 6 in 'کتاب صوتی [time : سی ثانیه] [player_setting : عقب بره]'
# Warning: Malformed annotation at 1 in 'لطفا [player_setting : به پخش کردن] [audiobook_name : پستچی] از [audiobook_author : یثربی] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 6 in 'لطفا [player_setting : به پخش کردن] [audiobook_name : پستچی] از [audiobook_author : یثربی] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 10 in 'لطفا [player_setting : به پخش کردن] [audiobook_name : پستچی] از [audiobook_author : یثربی] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 13 in 'لطفا [player_setting : به پخش کردن] [audiobook_name : پستچی] از [audiobook_author : یثربی] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 3 in 'من میخوام کتاب [time : هزار و یک شب] را از جایی که متوقف کرده بودم گوش بدم تا تمام بشه'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را مجدد پخش کن'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را از جایی که آخرین بار من متوقف کردم [player_setting : شروع به پخش کن]'
# Warning: Malformed annotation at 12 in '[audiobook_name : دا] را از جایی که آخرین بار من متوقف کردم [player_setting : شروع به پخش کن]'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 4 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 6 in 'میتونی کتاب صوتی مورد علاقه من [audiobook_name : دا] را پخش کنی'
# Warning: Malformed annotation at 7 in 'از جایی که آخرین بار متوقف کردم [audiobook_name : پستچی] را برای من پخش کن'
# Warning: Malformed annotation at 2 in 'علی کتاب [audiobook_name : پستچی] را از جایی که من آخرین بار متوقف کردم پخش کن'
# Warning: Malformed annotation at 3 in 'کتاب صوتی را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 0 in '[player_setting : به خواندن ادامه بده]'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 4 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 1 in 'کتاب [audiobook_name : دا] را پخش کن'
# Warning: Malformed annotation at 1 in 'دوباره [player_setting : شروع به پخش کن]'
# Warning: Malformed annotation at 0 in '[player_setting : ادامه] ی کتاب صوتی [audiobook_name : تاریخ روم] رو پخش کن'
# Warning: Malformed annotation at 6 in '[player_setting : ادامه] ی کتاب صوتی [audiobook_name : تاریخ روم] رو پخش کن'
# Warning: Malformed annotation at 0 in '[audiobook_name : پستچی] از [audiobook_author : یثربی] را پخش کن'
# Warning: Malformed annotation at 4 in '[audiobook_name : پستچی] از [audiobook_author : یثربی] را پخش کن'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 4 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 2 in 'خواندن کتاب [audiobook_name : دا] را برای من [player_setting : ادامه بده]'
# Warning: Malformed annotation at 8 in 'خواندن کتاب [audiobook_name : دا] را برای من [player_setting : ادامه بده]'
# Warning: Malformed annotation at 6 in 'گلچین کتاب صوتی اخیر من را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 2 in 'کتاب صوتی [audiobook_name : دا] را از جایی که من متوقف کردم [player_setting : پخش کن]'
# Warning: Malformed annotation at 12 in 'کتاب صوتی [audiobook_name : دا] را از جایی که من متوقف کردم [player_setting : پخش کن]'
# Warning: Malformed annotation at 3 in 'من میخوام کتاب [audiobook_author : نادر ابراهیمی] را گوش بدم'
# Warning: Malformed annotation at 2 in 'میتونی اخرین [media_type : کتاب صوتی] من را پخش کنی'
# Warning: Malformed annotation at 1 in 'میخوام [player_setting : از] جایی که آخرین بار رها کردم خواندن [media_type : کتاب صوتی] ام را [player_setting : ادامه] دهم'
# Warning: Malformed annotation at 11 in 'میخوام [player_setting : از] جایی که آخرین بار رها کردم خواندن [media_type : کتاب صوتی] ام را [player_setting : ادامه] دهم'
# Warning: Malformed annotation at 17 in 'میخوام [player_setting : از] جایی که آخرین بار رها کردم خواندن [media_type : کتاب صوتی] ام را [player_setting : ادامه] دهم'
# Warning: Malformed annotation at 0 in '[player_setting : از] جایی که [player_setting : آخرین بار] [media_type : کتاب صوتی] گوش دادم [player_setting : شروع] به پخش [player_setting : کن]'
# Warning: Malformed annotation at 5 in '[player_setting : از] جایی که [player_setting : آخرین بار] [media_type : کتاب صوتی] گوش دادم [player_setting : شروع] به پخش [player_setting : کن]'
# Warning: Malformed annotation at 9 in '[player_setting : از] جایی که [player_setting : آخرین بار] [media_type : کتاب صوتی] گوش دادم [player_setting : شروع] به پخش [player_setting : کن]'
# Warning: Malformed annotation at 15 in '[player_setting : از] جایی که [player_setting : آخرین بار] [media_type : کتاب صوتی] گوش دادم [player_setting : شروع] به پخش [player_setting : کن]'
# Warning: Malformed annotation at 20 in '[player_setting : از] جایی که [player_setting : آخرین بار] [media_type : کتاب صوتی] گوش دادم [player_setting : شروع] به پخش [player_setting : کن]'
# Warning: Malformed annotation at 4 in 'در پوشه ی رسانه [song_name : عشق] را پخش کن'
# Warning: Malformed annotation at 1 in 'می‌تونی [media_type : فایل صوتی] رو اول [player_setting : نگه داری و بزنی عقب] و بعدش پخش کنی'
# Warning: Malformed annotation at 7 in 'می‌تونی [media_type : فایل صوتی] رو اول [player_setting : نگه داری و بزنی عقب] و بعدش پخش کنی'
# Warning: Malformed annotation at 2 in 'می‌خوام اول [media_type : فایل صوتی] رو [player_setting : بزنی جلو] و بعد [player_setting : ادامه‌ش رو پخش کنی]'
# Warning: Malformed annotation at 7 in 'می‌خوام اول [media_type : فایل صوتی] رو [player_setting : بزنی جلو] و بعد [player_setting : ادامه‌ش رو پخش کنی]'
# Warning: Malformed annotation at 13 in 'می‌خوام اول [media_type : فایل صوتی] رو [player_setting : بزنی جلو] و بعد [player_setting : ادامه‌ش رو پخش کنی]'
# Warning: Malformed annotation at 0 in '[media_type : کتاب صوتی] [audiobook_name : دا] را پخش کن'
# Warning: Malformed annotation at 4 in '[media_type : کتاب صوتی] [audiobook_name : دا] را پخش کن'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را پخش کن'
# Warning: Malformed annotation at 0 in '[player_setting : برگرد به] [audiobook_name : دا]'
# Warning: Malformed annotation at 4 in '[player_setting : برگرد به] [audiobook_name : دا]'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 4 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 0 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 4 in '[audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 0 in '[media_type : کتاب صوتی] را دوباره پخش کن'
# Warning: Malformed annotation at 2 in 'پخش کننده [media_type : کتاب صوتی] را [player_setting : از سر بگیر]'
# Warning: Malformed annotation at 7 in 'پخش کننده [media_type : کتاب صوتی] را [player_setting : از سر بگیر]'
# Warning: Malformed annotation at 0 in '[media_type : کتاب صوتی] را مجدد پخش کن'
# Warning: Malformed annotation at 1 in 'لطفا [media_type : آهنگ] من را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 6 in 'لطفا [media_type : آهنگ] من را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 1 in 'لطفا [media_type : آهنگ] من را [player_setting : پخش کن]'
# Warning: Malformed annotation at 6 in 'لطفا [media_type : آهنگ] من را [player_setting : پخش کن]'
# Warning: Malformed annotation at 0 in '[audiobook_name : عمارت سرخ] را پخش کن'
# Warning: Malformed annotation at 0 in '[media_type : کتاب صوتی] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 5 in '[media_type : کتاب صوتی] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 3 in 'لطفا آهنگ های [music_genre : پاپ] مورد علاقه من را از لیست من پخش کن'
# Warning: Malformed annotation at 9 in 'من میخوام که تو آهنگ مورد علاقه من از [artist_name : یاس] را پخش کنی'
# Warning: Malformed annotation at 0 in '[player_setting : ادامه] ی [media_type : کتاب صوتی] رو پخش کن'
# Warning: Malformed annotation at 4 in '[player_setting : ادامه] ی [media_type : کتاب صوتی] رو پخش کن'
# Warning: Malformed annotation at 2 in 'به پخش [media_type : کتاب صوتی] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 6 in 'به پخش [media_type : کتاب صوتی] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 2 in 'میخوام بیشتر [media_type : کتاب صوتی] بشنوم'
# Warning: Malformed annotation at 0 in '[media_type : صوت] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 4 in '[media_type : صوت] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 0 in '[media_type : فایل صوتی] را پخش کن'
# Warning: Malformed annotation at 2 in 'کتاب صوتی [audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 6 in 'کتاب صوتی [audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 2 in 'به پخش [audiobook_name : دا] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 5 in 'به پخش [audiobook_name : دا] [player_setting : ادامه بده]'
# Warning: Malformed annotation at 1 in 'کتاب [audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 5 in 'کتاب [audiobook_name : دا] را [player_setting : از ادامه پخش کن]'
# Warning: Malformed annotation at 2 in 'olly میتونی [audiobook_name : چشم هایش] را پخش کنی'
# Warning: Malformed annotation at 2 in 'بیا به [audiobook_name : پستچی] گوش بدیم'
# Warning: Malformed annotation at 7 in 'من دوست دارم به گوش دادن به [media_type : کتاب صوتی] ام [player_setting : ادامه بدم]'
# Warning: Malformed annotation at 12 in 'من دوست دارم به گوش دادن به [media_type : کتاب صوتی] ام [player_setting : ادامه بدم]'
# Warning: Malformed annotation at 4 in 'من دوست دارم این [media_type : کتاب صوتی] را [player_setting : شروع کنم]'
# ...
# Warning: Malformed annotation at 17 in 'برای [relation : مامان] ایمیل بفرست تا به او بگویی [event_name : جشن تولد] [person : ندا] [date : یکشنبه] است'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [person : امیر] بفرست تا به او بگویم متشکرم'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [person : ندا] بفرست'
# Warning: Malformed annotation at 5 in 'آیا من ایمیل جدیدی از [person : ندا] دریافت کردم'
# Warning: Malformed annotation at 3 in 'من میخوام ایمیل [person : علی نوری] را پاسخ بدم'
# Warning: Malformed annotation at 2 in 'ایمیل‌ها ی [person : ارسلان] را چک کن'
# Warning: Malformed annotation at 1 in 'ایمیل‌های [relation : کارفرمای] من را بررسی کن'
# Warning: Malformed annotation at 2 in 'آیا به [person : علی] در مرد کنترل اسلحه ایمیل زدم'
# Warning: Malformed annotation at 1 in 'آیا [person : علی] در مورد مهمات به من ایمیل زده است'
# Warning: Malformed annotation at 4 in 'آیا من از یک [time : ساعت پیش] هیچ ایمیل جدیدی دارم'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [person : غلام] بنویس'
# Warning: Malformed annotation at 4 in 'لطفا یک ایمیل برای [relation : مامان] ارسال کن'
# Warning: Malformed annotation at 2 in 'اکنون به [relation : مامان] ایمیلی بزن'
# Warning: Malformed annotation at 4 in 'لطفا ایمیل را به [person : نصرت] ارسال کن'
# Warning: Malformed annotation at 4 in 'یک پیام ایمیل به [person : دنیا] بفرست سلام [date : امروز] چه کار می کنی'
# Warning: Malformed annotation at 9 in 'یک پیام ایمیل به [person : دنیا] بفرست سلام [date : امروز] چه کار می کنی'
# Warning: Malformed annotation at 1 in 'برنامه‌های [date : امروز] را برای [person : دنیا] ایمیل کن'
# Warning: Malformed annotation at 6 in 'برنامه‌های [date : امروز] را برای [person : دنیا] ایمیل کن'
# Warning: Malformed annotation at 6 in 'تمام ایمیل هایی که از طرف [relation : رئیس] برای من فرستاده شده را نشان بده'
# Warning: Malformed annotation at 4 in 'لطفاً یک ایمیل به [relation : عمو] [person : جواد] با عبارت زیر ارسال کن بله من می‌توانم آن را انجام دهم'
# Warning: Malformed annotation at 7 in 'لطفاً یک ایمیل به [relation : عمو] [person : جواد] با عبارت زیر ارسال کن بله من می‌توانم آن را انجام دهم'
# Warning: Malformed annotation at 0 in '[date : امروز] چند ایمیل جدید دریافت کردم'
# Warning: Malformed annotation at 4 in 'لطفاً یک ایمیل برای [relation : مامان] و [relation : بابا] بفرست که حالشان را بپرسی'
# Warning: Malformed annotation at 8 in 'لطفاً یک ایمیل برای [relation : مامان] و [relation : بابا] بفرست که حالشان را بپرسی'
# Warning: Malformed annotation at 5 in 'لطفا این ایمیل را برای [relation : دوست] من ارسال کن'
# Warning: Malformed annotation at 8 in 'ایمیل جدید را به مخاطبین من اضافه کن [email_address : نصرت اچ ات جیمیل دات کام]'
# Warning: Malformed annotation at 3 in 'پیام جدید به [email_address : جاوید ات جیمیل دات کام]'
# Warning: Malformed annotation at 1 in 'ایمیل‌های [person : علی] را چک کن'
# Warning: Malformed annotation at 2 in 'لطفا برای [relation : دوست] من [person : علی] یک ایمیل بفرست و بگو حالت چطور است'
# Warning: Malformed annotation at 6 in 'لطفا برای [relation : دوست] من [person : علی] یک ایمیل بفرست و بگو حالت چطور است'
# Warning: Malformed annotation at 4 in 'یک ایمیل جدید به [person : ندا امیری] بفرست'
# Warning: Malformed annotation at 1 in 'شماره [relation : مامان] را چک کن'
# Warning: Malformed annotation at 5 in 'می توانی یک ایمیل به [person : ماهان] بنویسی'
# Warning: Malformed annotation at 4 in 'در جواب ایمیل امروز [timeofday : صبح] [person : احمد] بنویس چهارصد و پنجاه'
# Warning: Malformed annotation at 7 in 'در جواب ایمیل امروز [timeofday : صبح] [person : احمد] بنویس چهارصد و پنجاه'
# Warning: Malformed annotation at 3 in 'در جواب ایمیل [relation : رئیس] بنویس فردا ساعت چهار عصر آنجا خواهم بود'
# Warning: Malformed annotation at 1 in 'آیا [relation : کارگر شرکت] من [personal_info : شماره‌ی تلفن خانه] دارد'
# Warning: Malformed annotation at 6 in 'آیا [relation : کارگر شرکت] من [personal_info : شماره‌ی تلفن خانه] دارد'
# Warning: Malformed annotation at 2 in 'ایمیلی که [time : نیم ساعت] پیش از [relation : مامان] ارسال شده چه می‌گوید'
# Warning: Malformed annotation at 8 in 'ایمیلی که [time : نیم ساعت] پیش از [relation : مامان] ارسال شده چه می‌گوید'
# Warning: Malformed annotation at 1 in 'برای [relation : رئیسم] ایمیل بنویس و بفرست'
# Warning: Malformed annotation at 1 in 'به [relation : رئیس] ایمیل بفرست و بگو دیر می‌رسم'
# Warning: Malformed annotation at 8 in 'من نیاز به یک ایمیل برای ارسال به [business_name : شرکت پارس آنلاین] در مورد مسائل خدماتم دارم'
# Warning: Malformed annotation at 6 in 'ایمیل را برای هر چیزی از [person : شراره] چک کن'
# Warning: Malformed annotation at 2 in 'آیا ایمیل [person : نصرت] یک پیوست داشت'
# Warning: Malformed annotation at 6 in 'آیا من هیچ ایمیل جدیدی از [person : آرش] دریافت کرده‌ام'
# Warning: Malformed annotation at 3 in 'آیا از ساعت [time : چهار] [date : امروز] تا الان هیچ ایمیل جدیدی رسیده'
# Warning: Malformed annotation at 6 in 'آیا از ساعت [time : چهار] [date : امروز] تا الان هیچ ایمیل جدیدی رسیده'
# Warning: Malformed annotation at 4 in 'آیا من ایمیلی از [person : پیام] دریافت کردم'
# Warning: Malformed annotation at 1 in 'آیا [person : علی] در دسترسه'
# Warning: Malformed annotation at 2 in 'آیا من [date : امروز] هیچ ایمیل جدیدی در [email_folder : صندوق ورودی] خودم دارم'
# Warning: Malformed annotation at 9 in 'آیا من [date : امروز] هیچ ایمیل جدیدی در [email_folder : صندوق ورودی] خودم دارم'
# Warning: Malformed annotation at 5 in 'شرکت فراگیر رایانه واقع در [place_name : شهرکرد چهارمحال و بختیاری] را به ایمیل‌های مخاطبین من اضافه کن'
# Warning: Malformed annotation at 1 in 'ایمیل [business_name : فروشگاه شهروند] را پیدا کن و آن را در [list_name : لیست مخاطبین] من قرار بده'
# Warning: Malformed annotation at 12 in 'ایمیل [business_name : فروشگاه شهروند] را پیدا کن و آن را در [list_name : لیست مخاطبین] من قرار بده'
# Warning: Malformed annotation at 6 in 'یک ایمیل در پاسخ به ایمیل [relation : مادر] من بنویس'
# Warning: Malformed annotation at 4 in 'من می‌خواهم به ایمیل [person : ساره] پاسخ دهم'
# Warning: Malformed annotation at 6 in 'چند نفر از مخاطبین من در [place_name : رشت] زندگی یا کار می‌کنند'
# Warning: Malformed annotation at 3 in 'می‌تونی لطفا به [person : جمشید] ایمیل بزنی بگی که من در مرخصی هستم'
# Warning: Malformed annotation at 4 in 'به ایمیل من از [person : علی] اکبری پاسخ بده و به آنها اطلاع بده که [date : فردا] آنها را خواهم دید'
# Warning: Malformed annotation at 16 in 'به ایمیل من از [person : علی] اکبری پاسخ بده و به آنها اطلاع بده که [date : فردا] آنها را خواهم دید'
# Warning: Malformed annotation at 4 in 'لطفا ایمیل جدید از [person : علی] را چک کن'
# Warning: Malformed annotation at 2 in 'آخرین ایمیل‌های [business_name : آمازون] را به من نشان بده'
# Warning: Malformed annotation at 1 in 'آیا [date : امروز] هیچ ایمیل جدیدی برای من وجود دارد'
# Warning: Malformed annotation at 1 in 'ایمیل‌های [time : ده دقیقه‌ی گذشته]'
# Warning: Malformed annotation at 4 in 'ساعت مصاحبه از ایمیل [date : دیروز] چند است'
# Warning: Malformed annotation at 2 in 'اطلاعات تماس [person : عادل] را نمایش بده'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [email_address : امیراسدی ات جیمیل دات کام] ارسال کن'
# Warning: Malformed annotation at 11 in 'یک ایمیل جدید بنویس اما من این بار آدرس جدید گرفتم [email_address : براندون ات اگزمپل دات کام]'
# Warning: Malformed annotation at 0 in '[personal_info : شماره‌ی تلفن] [business_name : آقای احمدی] در مخاطبین من چیست'
# Warning: Malformed annotation at 4 in '[personal_info : شماره‌ی تلفن] [business_name : آقای احمدی] در مخاطبین من چیست'
# Warning: Malformed annotation at 2 in 'آیا از [timeofday : ظهر] ایمیلی دریافت کرده‌ام'
# Warning: Malformed annotation at 1 in 'ایا [person : ندا] هیچ ایمیلی در مورد [person : علی] برایم فرستاده'
# Warning: Malformed annotation at 8 in 'ایا [person : ندا] هیچ ایمیلی در مورد [person : علی] برایم فرستاده'
# Warning: Malformed annotation at 2 in 'وقتی از [person : علی] ایمیلی دریافت می‌کنم صدای بیپ را بزن'
# Warning: Malformed annotation at 1 in 'لطفا [email_address : ایمیل] [person : احمد شکوری] رو به فهرست مخاطبین اضافه کن.'
# Warning: Malformed annotation at 4 in 'لطفا [email_address : ایمیل] [person : احمد شکوری] رو به فهرست مخاطبین اضافه کن.'
# Warning: Malformed annotation at 5 in 'من در آخرین ایمیلم به [person : صنم] چه گفتم'
# Warning: Malformed annotation at 0 in '[person : مهتاب] را از مخاطبین من پیدا کن و برایش ایمیل بفرست'
# Warning: Malformed annotation at 1 in 'به [person : ناهید] برای [event_name : تولدش] ایمیل بزن'
# Warning: Malformed annotation at 5 in 'به [person : ناهید] برای [event_name : تولدش] ایمیل بزن'
# Warning: Malformed annotation at 1 in 'چند [personal_info : شماره‌ی تلفن] برای [person : نصرت] دارم'
# Warning: Malformed annotation at 6 in 'چند [personal_info : شماره‌ی تلفن] برای [person : نصرت] دارم'
# Warning: Malformed annotation at 2 in 'در مورد [event_name : جلسه] به [person : ماهان] ایمیل بزن'
# Warning: Malformed annotation at 6 in 'در مورد [event_name : جلسه] به [person : ماهان] ایمیل بزن'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [person : ماهان] بفرست که او [timeofday : امشب] چه ساعتی به خانه خواهد آمد'
# Warning: Malformed annotation at 9 in 'یک ایمیل به [person : ماهان] بفرست که او [timeofday : امشب] چه ساعتی به خانه خواهد آمد'
# Warning: Malformed annotation at 1 in 'به [person : علی آهنگر] ایمیل بزن'
# Warning: Malformed annotation at 4 in 'شروع کن و به [person : علی نوری] ایمیل بده'
# Warning: Malformed annotation at 5 in 'آیا من هیچ ایمیلی از [person : علی فرهادی] دریافت کرده ام'
# Warning: Malformed annotation at 0 in '[personal_info : شماره‌ی تلفن] [person : ماهان]'
# Warning: Malformed annotation at 4 in '[personal_info : شماره‌ی تلفن] [person : ماهان]'
# Warning: Malformed annotation at 2 in 'به ایمیل [person : علی] پاسخ بده'
# Warning: Malformed annotation at 1 in 'برای [relation : مادربزرگ] ایمیل بفرست و بنویس شنبه می رسیم. می بینمت.'
# Warning: Malformed annotation at 4 in 'لطفا تمام ایمیل‌های جدید [business_name : اداره‌ی مالیات بر درآمد] را بررسی کن'
# Warning: Malformed annotation at 2 in 'لطفا یک [personal_info : شماره] تماس از [person : جاوید] پیدا کن و به من بگو'
# Warning: Malformed annotation at 7 in 'لطفا یک [personal_info : شماره] تماس از [person : جاوید] پیدا کن و به من بگو'
# Warning: Malformed annotation at 2 in 'ایا ما [personal_info : شماره دفتر] [person : ندا] را داریم'
# Warning: Malformed annotation at 6 in 'ایا ما [personal_info : شماره دفتر] [person : ندا] را داریم'
# Warning: Malformed annotation at 4 in 'هر ایمیل جدیدی از [person : علی]'
# Warning: Malformed annotation at 4 in 'لطفا به ایمیلی که [person : علی] برایم فرستاده بگو من به پول نیاز دارم اکنون فوری است'
# Warning: Malformed annotation at 1 in 'آیا [person : ژاله امیری] به من پیام داده'
# Warning: Malformed annotation at 1 in 'به [person : آزاده] ایمیل بزن'
# Warning: Malformed annotation at 1 in 'به [relation : مامان] ایمیل بزن و بپرس آب و هوای اونجا چطوره'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [email_address : علی ات جیمیل دات کام] بنویس'
# Warning: Malformed annotation at 2 in 'به آیدی [email_address : تیم ات هاتمیل دات کام] ایمیل بفرست'
# Warning: Malformed annotation at 8 in 'یک ایمیل جدید در مخاطبین من به نام [person : علی] ایجاد کن'
# Warning: Malformed annotation at 3 in 'آیا ایمیل جدیدی [time : بعد از ساعت چهار] [date : امروز] دریافت شده است'
# Warning: Malformed annotation at 9 in 'آیا ایمیل جدیدی [time : بعد از ساعت چهار] [date : امروز] دریافت شده است'
# Warning: Malformed annotation at 9 in 'با اسنادی که اخیراً ذخیره کرده‌ام یک ایمیل برای [relation : کارگر شرکت] من ایجاد کن'
# Warning: Malformed annotation at 4 in 'ایمیل های جدید از [person : ساره] را برایم چک کن'
# Warning: Malformed annotation at 0 in '[personal_info : ایمیل] [person : علی] چیست'
# Warning: Malformed annotation at 3 in '[personal_info : ایمیل] [person : علی] چیست'
# Warning: Malformed annotation at 5 in 'هر ایمیل دریافتی در یک [time : ساعت گذشته] را به من نشان بده'
# Warning: Malformed annotation at 0 in '[personal_info : جزئیات مخاطب] [person : امیر]'
# Warning: Malformed annotation at 4 in '[personal_info : جزئیات مخاطب] [person : امیر]'
# Warning: Malformed annotation at 3 in 'یک ایمیل به [person : ندا] بفرست'
# Warning: Malformed annotation at 2 in 'همه نامه‌های [person : دیجی کالا] را بررسی کن'
# Warning: Malformed annotation at 3 in 'فرم را به [relation : نائب رئیس منطقه‌ای] ایمیل کن'
# Warning: Malformed annotation at 8 in 'از آخرین باری که چک کردیم در صندوق [email_folder : ورودی] من ایمیل جدیدی هست'
# Warning: Malformed annotation at 4 in 'سلام یک ایمیل به [person : علی] بفرست'
# Warning: Malformed annotation at 0 in '[relation : دوستم] [person : دارا] برای من یک دعوتنامه فرستاده که بروم به خانه‌ای که تازه خریده یک تشکر به آیدی ایمیلش بفرست'
# Warning: Malformed annotation at 3 in '[relation : دوستم] [person : دارا] برای من یک دعوتنامه فرستاده که بروم به خانه‌ای که تازه خریده یک تشکر به آیدی ایمیلش بفرست'
# Warning: Malformed annotation at 8 in 'ایمیل من را برای هر ایمیل جدیدی از [person : جواد] چک کن'
# Warning: Malformed annotation at 5 in 'آیا من ایمیل جدیدی از [person : جواد] دارم'
# Warning: Malformed annotation at 1 in 'وقتی [person : امیر] به من ایمیل زد به من اطلاع بده'
# Warning: Malformed annotation at 1 in 'آیا [person : امیر] برای من ایمیل فرستاده است'
# Epoch 1/7
# 100%|██████████| 720/720 [04:37<00:00,  2.60it/s]
# Slot Loss: 0.0, Intent Loss: 1.584055765469869, Intent Accuracy: 0.6139482369289561
# Validation Slot Filling Metrics:
#               precision    recall  f1-score   support
#
#            O       1.00      1.00      1.00     14907
#
#     accuracy                           1.00     14907
#    macro avg       1.00      1.00      1.00     14907
# weighted avg       1.00      1.00      1.00     14907
#
# Validation Intent Accuracy: 0.8199704869650762
# Saved best model.
# Epoch 2/7
# 100%|██████████| 720/720 [04:42<00:00,  2.55it/s]
# Slot Loss: 0.0, Intent Loss: 0.6125061470497813, Intent Accuracy: 0.8454924439812402
# Validation Slot Filling Metrics:
#               precision    recall  f1-score   support
#
#            O       1.00      1.00      1.00     14907
#
#     accuracy                           1.00     14907
#    macro avg       1.00      1.00      1.00     14907
# weighted avg       1.00      1.00      1.00     14907
#
# Validation Intent Accuracy: 0.8440727988194786
# Epoch 3/7
# 100%|██████████| 720/720 [04:43<00:00,  2.54it/s]
# Slot Loss: 0.0, Intent Loss: 0.40910950446656597, Intent Accuracy: 0.8931735278791036
# Validation Slot Filling Metrics:
#               precision    recall  f1-score   support
#
#            O       1.00      1.00      1.00     14907
#
#     accuracy                           1.00     14907
#    macro avg       1.00      1.00      1.00     14907
# weighted avg       1.00      1.00      1.00     14907
#
# Validation Intent Accuracy: 0.8568617806197737
# Epoch 4/7
# 100%|██████████| 720/720 [04:43<00:00,  2.54it/s]
# Slot Loss: 0.0, Intent Loss: 0.2975295186236811, Intent Accuracy: 0.9206183776272364
# Validation Slot Filling Metrics:
#               precision    recall  f1-score   support
#
#            O       1.00      1.00      1.00     14907
#
#     accuracy                           1.00     14907
#    macro avg       1.00      1.00      1.00     14907
# weighted avg       1.00      1.00      1.00     14907
#
# Validation Intent Accuracy: 0.8637481554353172
# Epoch 5/7
# 100%|██████████| 720/720 [04:43<00:00,  2.54it/s]
# Slot Loss: 0.0, Intent Loss: 0.20299717771639633, Intent Accuracy: 0.9446760465520236
# Validation Slot Filling Metrics:
#               precision    recall  f1-score   support
#
#            O       1.00      1.00      1.00     14907
#
#     accuracy                           1.00     14907
#    macro avg       1.00      1.00      1.00     14907
# weighted avg       1.00      1.00      1.00     14907
#
# Validation Intent Accuracy: 0.8666994589276931
# Early stopping triggered.
# Test Slot Filling Metrics:
#               precision    recall  f1-score   support
#
#            O       1.00      1.00      1.00     21834
#
#     accuracy                           1.00     21834
#    macro avg       1.00      1.00      1.00     21834
# weighted avg       1.00      1.00      1.00     21834
#
# Test Intent Accuracy: 0.8651647612642905
# Predictions saved to persian_joint_bert_test_set_predictions.csv

# %%
total_params_fa = sum(p.numel() for p in model.parameters())
print(f"Total parameters for joint bert used Persian dataset: {total_params_fa}")
# Out:
# Total parameters for joint bert used Persian dataset: 277499965

# %% [markdown]
# ##Roberta model for english intent classification
#
# ```
# # This is formatted as code
# ```

# %%
import json
import random
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import RobertaForSequenceClassification, RobertaTokenizer, AdamW, get_linear_schedule_with_warmup
from torch.nn import CrossEntropyLoss
import numpy as np
from tqdm import tqdm
from sklearn.metrics import f1_score, precision_recall_fscore_support, accuracy_score

massive_raw_en = []
with open('/content/1.0/data/en-US.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        massive_raw_en.append(json.loads(line))

(train_data, val_data, test_data, tag2id, intent2id) = Read_Massive_dataset(massive_raw_en)

# Tokenize the sentences
tokenizer = RobertaTokenizer.from_pretrained('roberta-large')

def encode_data(sentences, intents, tokenizer, intent2id):
    encodings = tokenizer(sentences, is_split_into_words=True, padding=True, truncation=True, max_length=128, return_tensors='pt')
    intent_labels = [intent2id[intent] for intent in intents]
    return encodings, torch.tensor(intent_labels)

# Encode data
train_encodings, train_intents = encode_data(train_data[0], train_data[2], tokenizer, intent2id)
val_encodings, val_intents = encode_data(val_data[0], val_data[2], tokenizer, intent2id)


def convert_to_tensor(encodings, labels):
    input_ids = encodings['input_ids']
    attention_mask = encodings['attention_mask']
    labels = labels
    return TensorDataset(input_ids, attention_mask, labels)

train_dataset = convert_to_tensor(train_encodings, train_intents)
val_dataset = convert_to_tensor(val_encodings, val_intents)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# Model initialization
model_en = RobertaForSequenceClassification.from_pretrained('roberta-large',
                                                            num_labels=len(intent2id))

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_en = model_en.to(device)

optimizer = AdamW(model_en.parameters(), lr=1e-5, weight_decay=0.01) 

# Scheduler for learning rate
total_steps = len(train_loader) * 10 
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

loss_fn = CrossEntropyLoss()

def train_epoch(model, data_loader, optimizer, scheduler, device, loss_fn):
    model.train()
    total_loss = 0
    correct_predictions = 0

    for data in tqdm(data_loader):
        input_ids, attention_mask, labels = [t.to(device) for t in data]

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()

        logits = outputs.logits
        _, preds = torch.max(logits, dim=1)
        correct_predictions += torch.sum(preds == labels).item()

        loss.backward()
        optimizer.step()
        scheduler.step()  # Step the scheduler after each batch

    return correct_predictions / len(data_loader.dataset), total_loss / len(data_loader)

def eval_model(model, data_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data in data_loader:
            input_ids, attention_mask, labels = [t.to(device) for t in data]

            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            logits = outputs.logits
            _, preds = torch.max(logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate both micro and macro metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision_micro, recall_micro, f1_micro, _ = precision_recall_fscore_support(all_labels, all_preds, average='micro')
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')

    return {
        'accuracy': accuracy,
        'precision_micro': precision_micro,
        'recall_micro': recall_micro,
        'f1_micro': f1_micro,
        'precision_macro': precision_macro,
        'recall_macro': recall_macro,
        'f1_macro': f1_macro
    }

# Early stopping parameters
patience = 3
best_val_f1 = float('-inf')
early_stop_counter = 0

# Training loop
epochs = 10  
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    train_acc, train_loss = train_epoch(model_en, train_loader, optimizer, scheduler, device, loss_fn)
    print(f"Train loss: {train_loss}, accuracy: {train_acc}")

    val_metrics = eval_model(model_en, val_loader, device)
    print(f"Validation Metrics:")
    print(f"  Accuracy: {val_metrics['accuracy']}")
    print(f"  Micro - Precision: {val_metrics['precision_micro']}, Recall: {val_metrics['recall_micro']}, F1: {val_metrics['f1_micro']}")
    print(f"  Macro - Precision: {val_metrics['precision_macro']}, Recall: {val_metrics['recall_macro']}, F1: {val_metrics['f1_macro']}")

    # Early stopping check
    if val_metrics['f1_macro'] > best_val_f1:
        best_val_f1 = val_metrics['f1_macro']
        early_stop_counter = 0
        model_en.save_pretrained('en_roberta_large_best.bin')  # Save the best model
    else:
        early_stop_counter += 1
        if early_stop_counter >= patience:
            print("Early stopping triggered.")
            break
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10
# 100%|██████████| 360/360 [04:43<00:00,  1.27it/s]
# Train loss: 1.980842079801692, accuracy: 0.5708702449192288
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8504672897196262
#   Micro - Precision: 0.8504672897196262, Recall: 0.8504672897196262, F1: 0.8504672897196262
#   Macro - Precision: 0.7587096216384056, Recall: 0.7494755821972547, F1: 0.7481035717842383
# Epoch 2/10
# 100%|██████████| 360/360 [04:43<00:00,  1.27it/s]
# Train loss: 0.604397638183501, accuracy: 0.8737189508424527
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8834235120511559
#   Micro - Precision: 0.8834235120511559, Recall: 0.8834235120511559, F1: 0.8834235120511559
#   Macro - Precision: 0.8231680229865462, Recall: 0.8244824159643258, F1: 0.8214460138461742
# Epoch 3/10
# 100%|██████████| 360/360 [04:43<00:00,  1.27it/s]
# Train loss: 0.3903548603463504, accuracy: 0.9142782699322564
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8878504672897196
#   Micro - Precision: 0.8878504672897196, Recall: 0.8878504672897196, F1: 0.8878504672897196
#   Macro - Precision: 0.832011350235342, Recall: 0.8331037932156097, F1: 0.8296259937148008
# Epoch 4/10
# 100%|██████████| 360/360 [04:42<00:00,  1.27it/s]
# Train loss: 0.27932294765487314, accuracy: 0.9375542817439638
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8996556812592228
#   Micro - Precision: 0.8996556812592228, Recall: 0.8996556812592228, F1: 0.8996556812592228
#   Macro - Precision: 0.8727984594788777, Recall: 0.8685618938686809, F1: 0.8618127093840361
# Epoch 5/10
# 100%|██████████| 360/360 [04:42<00:00,  1.27it/s]
# Train loss: 0.21499192483930124, accuracy: 0.9534479763765851
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8912936546974914
#   Micro - Precision: 0.8912936546974914, Recall: 0.8912936546974914, F1: 0.8912936546974914
#   Macro - Precision: 0.8742172000099838, Recall: 0.8810205962397796, F1: 0.8713752718780203
# Epoch 6/10
# 100%|██████████| 360/360 [04:42<00:00,  1.27it/s]
# Train loss: 0.16555898034324248, accuracy: 0.9649122807017544
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.9016232169208067
#   Micro - Precision: 0.9016232169208067, Recall: 0.9016232169208067, F1: 0.9016232169208067
#   Macro - Precision: 0.8796417172482971, Recall: 0.8812942223045661, F1: 0.8767955831772343
# Epoch 7/10
# 100%|██████████| 360/360 [04:42<00:00,  1.28it/s]
# Train loss: 0.1314190384414461, accuracy: 0.9729025534132361
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.9016232169208067
#   Micro - Precision: 0.9016232169208067, Recall: 0.9016232169208067, F1: 0.9016232169208067
#   Macro - Precision: 0.8821965623945655, Recall: 0.8872866927613574, F1: 0.8803328810369219
# Epoch 8/10
# 100%|██████████| 360/360 [04:42<00:00,  1.27it/s]
# Train loss: 0.10953676234413352, accuracy: 0.9781136008337676
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.8991637973438269
#   Micro - Precision: 0.8991637973438269, Recall: 0.8991637973438269, F1: 0.8991637973438269
#   Macro - Precision: 0.8760095905938026, Recall: 0.8810090302844413, F1: 0.8747637579049774
# Epoch 9/10
# 100%|██████████| 360/360 [04:42<00:00,  1.27it/s]
# Train loss: 0.09464016573296653, accuracy: 0.9822824387701928
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Validation Metrics:
#   Accuracy: 0.9016232169208067
#   Micro - Precision: 0.9016232169208067, Recall: 0.9016232169208067, F1: 0.9016232169208067
#   Macro - Precision: 0.8833560652843553, Recall: 0.8903175536265076, F1: 0.882459663520674
# Epoch 10/10
# 100%|██████████| 360/360 [04:42<00:00,  1.28it/s]
# Train loss: 0.08668375316386422, accuracy: 0.9834983498349835
# Validation Metrics:
#   Accuracy: 0.9021151008362026
#   Micro - Precision: 0.9021151008362026, Recall: 0.9021151008362026, F1: 0.9021151008362026
#   Macro - Precision: 0.8827996102378552, Recall: 0.89066263470081, F1: 0.8823660523695194
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
total_params = sum(p.numel() for p in model_en.parameters())
print(f"Total number of parameters for roberta-large (used for EN intent detection): {total_params}")
# Out:
# Total number of parameters for roberta-large (used for EN intent detection): 355421244

# %%
# Function to predict for entire test set
def predict_example(text, tokenizer, model, intent2id):
    encoding = tokenizer(text, padding=True, truncation=True, max_length=128, return_tensors='pt')
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)

    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=1).item()
    predicted_intent = list(intent2id.keys())[list(intent2id.values()).index(predicted_class)]
    return predicted_intent

# %%
import pandas as pd
results = []

for idx, (sentence, true_intent, id) in enumerate(zip(test_data[0], test_data[2], [entry['id'] for entry in massive_raw_en if entry['partition'] == 'test'])):
    text = ' '.join(sentence)  # Join tokens into text
    predicted_intent = predict_example(text, tokenizer, model_en, intent2id)
    results.append({
        'id': id,
        'text': text,
        'true_intent': true_intent,
        'predicted_intent': predicted_intent
    })

df_results = pd.DataFrame(results)
df_results.to_csv('en_roberta_test_set_predictions.csv', index=False)

print("Predictions saved to 'test_set_predictions.csv'")
# Out:
# Predictions saved to 'test_set_predictions.csv'
